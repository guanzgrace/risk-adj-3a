# %%
import pandas as pd
from scipy.stats.stats import pearsonr
from scipy import stats
from scipy import special
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
data2014 = pd.read_csv("Our_Dataset/2014dataset.csv")
data2015 = pd.read_csv("Our_Dataset/2015dataset.csv")
data2016 = pd.read_csv("Our_Dataset/2016dataset.csv")
data2017 = pd.read_csv("Our_Dataset/2017dataset.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,52,323,649,882,932,1092,1202) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,57,204,341,376,377,396,430,431,928,944,1006,1013,1151,1160,1169,1179,1411) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,17,163,355,406,702,835,847,1083,1156,1183,1185,1200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Create the labels.
# By index:
# label 2 is transfers
# label 3 is premiums
# label 4 is costs
# label 5 is member months
# label 6 is reinsurance (individual group only)

ind_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                  "HHS RISK ADJUSTMENT TRANSFER AMOUNT (INDIVIDUAL MARKET, INCLUDING CATASTROPHIC)",
                  "1.1Directpremiumwritten2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "2.16Totalincurredclaims2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "7.4Membermonths2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "STATE", "REINSURANCE PAYMENT AMOUNT (OR NOT ELIGIBLE)"] # no more reinsurance as of 2017
ind_labels_15 = [label.replace('15', '16') for label in ind_labels_14]
ind_labels_16 = [label.replace('15', '17') for label in ind_labels_14]
ind_labels_17 = [label.replace('15', '18') for label in ind_labels_14][:-1]

sg_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                 "HHS RISK ADJUSTMENT TRANSFERS AMOUNT (SMALL GROUP MARKET)",
                  "1.1Directpremiumwritten7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "2.16Totalincurredclaims7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "7.4Membermonths7HealthInsuranceSMALLGROUPTotalasof3/31/15", "STATE"]
sg_labels_15 = [label.replace('15', '16') for label in sg_labels_14]
sg_labels_16 = [label.replace('15', '17') for label in sg_labels_14]
sg_labels_17 = [label.replace('15', '18') for label in sg_labels_14]

# %%
# Filter the data to include only the fields we want

ind_data_14 = data2014[ind_labels_14].dropna()
ind_data_15 = data2015[ind_labels_15].dropna()
ind_data_16 = data2016[ind_labels_16].dropna()
ind_data_17 = data2017[ind_labels_17].dropna()
sg_data_14 = data2014[sg_labels_14].dropna()
sg_data_15 = data2015[sg_labels_15].dropna()
sg_data_16 = data2016[sg_labels_16].dropna()
sg_data_17 = data2017[sg_labels_17].dropna()

# %%
# Drop companies with <2000 MM
ind_data_14 = ind_data_14.where(ind_data_14[ind_labels_14[5]] > 2000).dropna()
ind_data_15 = ind_data_15.where(ind_data_15[ind_labels_15[5]] > 2000).dropna()
ind_data_16 = ind_data_16.where(ind_data_16[ind_labels_16[5]] > 2000).dropna()
ind_data_17 = ind_data_17.where(ind_data_17[ind_labels_17[5]] > 2000).dropna()
sg_data_14 = sg_data_14.where(sg_data_14[sg_labels_14[5]] > 2000).dropna()
sg_data_15 = sg_data_15.where(sg_data_15[sg_labels_15[5]] > 2000).dropna()
sg_data_16 = sg_data_16.where(sg_data_16[sg_labels_16[5]] > 2000).dropna()
sg_data_17 = sg_data_17.where(sg_data_17[sg_labels_17[5]] > 2000).dropna()

# %%
# Calculate transfers, premiums, costs, and reinsurance (if individual group) per member month
def calculate_pmm(df, df_labels, group):
    df["MM"] = df[df_labels[5]]
    df["Transfers"] = df[df_labels[2]]
    df["Enrollees"] = df["MM"] / 12
    df["TransfersPerEnrollee"] = df["Transfers"] / df["Enrollees"]
    df["TransfersPerSqrtEnrollee"] = df["Transfers"] / np.sqrt(df["Enrollees"])
    df["LogEnrollees"] = np.log(df["Enrollees"])
    df["LogTransfers"] = np.log(df["Transfers"]**2 + 1)
    df["TransfersPMM"] = df[df_labels[2]] / df[df_labels[5]]
    df["PremiumsPMM"] = abs(df[df_labels[3]] / df[df_labels[5]])
    df["CostsPMM"] = abs(df[df_labels[4]] / df[df_labels[5]])
    if group == "i":
        df["ReinsurancePMM"] = df[df_labels[7]] / df[df_labels[5]]
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"] + df["ReinsurancePMM"]
        #df["PremMinusCostsPlusReinsurancePMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["ReinsurancePMM"]
    elif group == "sg":
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["PremMinusCostsPMM"] = df["PremiumsPMM"] - df["CostsPMM"]
    df["PremMinusCostsPlusTransfersPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["SicknessPMM"] = df["CostsPMM"] - df["PremiumsPMM"]
    average_sickness = np.mean(df["SicknessPMM"])
    df["ExcessSicknessPMM"] = df["SicknessPMM"] - average_sickness
    return df

ind_data_14 = calculate_pmm(ind_data_14, ind_labels_14, "i")
ind_data_15 = calculate_pmm(ind_data_15, ind_labels_15, "i")
ind_data_16 = calculate_pmm(ind_data_16, ind_labels_16, "i")
ind_data_17 = calculate_pmm(ind_data_17, ind_labels_17, "sg")
sg_data_14 = calculate_pmm(sg_data_14, sg_labels_14, "sg")
sg_data_15 = calculate_pmm(sg_data_15, sg_labels_15, "sg")
sg_data_16 = calculate_pmm(sg_data_16, sg_labels_16, "sg")
sg_data_17 = calculate_pmm(sg_data_17, sg_labels_17, "sg")

# %%
# Combine the dataframes by left merging

ind_data = ind_data_14.merge(ind_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(ind_data_16, on='HIOS ID', how='outer').merge(ind_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
# Do the same thing for small group

sg_data = sg_data_14.merge(sg_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(sg_data_16, on='HIOS ID', how='outer').merge(sg_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
sg_data.shape
# Out:
# (611, 85)

# %%
def plot(df, label, show_graphs):
    no_nulls = df[['LogEnrollees', 'LogTransfers']].dropna()
    X = no_nulls[['LogEnrollees']]
    y = no_nulls['LogTransfers']
    X = sm.add_constant(X)
    est = sm.OLS(y, X).fit()
    equation = "Log T = %f + %f * Log Enrollees" % (est.params[0], est.params[1])
    if show_graphs:
        fig, ax = plt.subplots(figsize=(8,8))
        plt.scatter(df["LogEnrollees"], df["LogTransfers"])
        x = np.linspace(min(df["LogEnrollees"]), max(df["LogEnrollees"]), 1000)
        plt.plot(x, est.params[0] + est.params[1] * x, label=equation)
        plt.title(label)
        plt.xlabel("Log # Enrollees")
        plt.ylabel("Log Transfers^2 + 1")
        plt.legend()
        plt.show()
    print(label)
    print(equation)
    
def state(df, state):
    return df.where(df["STATE"] == state).where(df["LogTransfers"] > 2).dropna()

def remove_outliers(df):
    return df.where(df["LogTransfers"] > 2).dropna()

# %%
def erfinv2(sample_size):# sig):
    # erf inverse 0.5 * p/k where p=0.05
    print("Sample size %d" % (sample_size))
    return special.erfinv(1-0.5*0.05/sample_size) * np.sqrt(2)# * sig

def num_pass(df, a):
    sample_size = df.shape[0]
    count = 0
    delta = erfinv2(sample_size)
    print("Delta_0 % .3f" % (delta))
    es1 = max(abs(df["TransfersPerSqrtEnrollee"])) / delta
    print("Comparison es_0 = %.3f" % (es1))
    print("Comparison es_0*%.2f = %.3f" % (a, a*es1))
    
    for index, row in df.iterrows():
        t = row["Transfers"]
        n = row["Enrollees"]
        if abs(row["TransfersPerSqrtEnrollee"]) < a*es1:
            count += 1
            print("T/sqrt(N)=%.3f \t <a*es_0 Satisfied" % (row["TransfersPerSqrtEnrollee"]))
        else:
            print("T/sqrt(N)=%.3f \t <a*es_0 NOT Satisfied \t Distance |T/sqrt(N)|-a*es_0 %.1f " % (row["TransfersPerSqrtEnrollee"], abs(row["TransfersPerSqrtEnrollee"]) - a*es1))
    return count
    
def binom(k, n, p):
    return stats.binom.cdf(k, n, p)

# %%
def run_stat_test(data, label, a):
    print(label)
    p01 = special.erf(a/np.sqrt(2))
    print("P01 = %.3f" % (p01))
    successes = num_pass(data, a)
    print("Number of successes: %d" % (successes))
    print("P value = %.3f" % (1- binom(successes, data.shape[0], p01)))

# %%
def ratio(df, v):# sig):
    # # of people where |d_i| < v
    return df["TransfersPerSqrtEnrollee"].where(abs(df["TransfersPerSqrtEnrollee"]) < v).dropna().count() / df["TransfersPerSqrtEnrollee"].count()

def ratio_list(t, v):# sig):
    # # of people where |d_i| < v
    k = len(t)
    t2 = [x for x in t if abs(x) < v]
    return len(t2) / k

# %%
#df = state(sg_data_14, "NY")
#k = len(df)
#v = np.linspace(0, max(df["TransfersPerSqrtEnrollee"]), 1000)
#v = v[1:len(v)-2]

# %%
this_nb_state = "CA"

df2 = state(sg_data_14, this_nb_state)["TransfersPerSqrtEnrollee"]
df2 = df2.append(state(sg_data_15, this_nb_state)["TransfersPerSqrtEnrollee"]) 
df2 = df2.append(state(sg_data_16, this_nb_state)["TransfersPerSqrtEnrollee"]) 
df2 = df2.append(state(sg_data_17, this_nb_state)["TransfersPerSqrtEnrollee"])

def add_states(df2, state_to_add):
    df2 = df2.append(state(sg_data_14, state_to_add)["TransfersPerSqrtEnrollee"])
    df2 = df2.append(state(sg_data_15, state_to_add)["TransfersPerSqrtEnrollee"]) 
    df2 = df2.append(state(sg_data_16, state_to_add)["TransfersPerSqrtEnrollee"]) 
    df2 = df2.append(state(sg_data_17, state_to_add)["TransfersPerSqrtEnrollee"])
    return df2

df2 = add_states(df2, "NY")
df2 = add_states(df2, "WI")
df2 = add_states(df2, "PA")
df2 = add_states(df2, "OR")
df2 = add_states(df2, "NV")
df2 = add_states(df2, "FL")
df2 = add_states(df2, "VA")
df2 = add_states(df2, "AZ")
df2 = add_states(df2, "GA")
df2 = add_states(df2, "CO")
df2 = add_states(df2, "MI")
df2 = add_states(df2, "ME")
df2 = add_states(df2, "MO")
df2 = add_states(df2, "OH")
df2 = add_states(df2, "NM")
df2 = add_states(df2, "CT")
df2 = add_states(df2, "NE")
df2 = add_states(df2, "HI")
df2 = add_states(df2, "MN")
df2 = add_states(df2, "AR")
df2 = add_states(df2, "NJ")
df2 = add_states(df2, "MD")
df2 = add_states(df2, "WA")
df2 = add_states(df2, "UT")

# PA WI OR NV FL VA NY AZ GA CO MI ME CA MO OH NM CT MA NE HI MN AR NJ MD WA UT

# %%
this_nb_state = "mixed"

# %%
k = len(df2)
v = np.linspace(0, max(abs(df2)), 1000)
v = v[1:len(v)]

ratios = [ratio_list(df2, vi) for vi in v]
#print(ratios)
begin_p = 5/k
end_p = 1-begin_p
start_index = 0
end_index = 0
for index, ratio2 in enumerate(ratios):
    if ratio2 >= begin_p:
        start_index = index
        break
    
for index, ratio2 in enumerate(ratios):
    if ratio2 > end_p:
        end_index = index
        break

if end_index == 0:
    end_index = len(v) - 1
    
v = v[start_index:end_index]

ratios2 = ratios[start_index:end_index]
multiplier = [np.sqrt(2)/vi for vi in v]

# %%
plt.plot(v, ratios2)
plt.plot(v, multiplier)

# %%
y = [multiplier[i] * special.erfinv(ratio2) for i, ratio2 in enumerate(ratios2)]
plt.plot(v, y)
plt.title("1/beta vs. v")
# Out:
# Text(0.5,1,'1/beta vs. v')

# %%
beta = [1/yi for yi in y]
plt.plot(v, beta)
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
plt.title("beta vs. v")
# Out:
# Text(0.5,1,'beta vs. v')

# %%
# Finding the minimum beta
# Whenever we reject a beta, we reject all betas greater than that,
# so keep pushing beta smaller until we reach max_difference == test_statistic
# Run test for larger data sizes (combining states, years)

# %%
max_beta=max(beta)

# %%
max_beta = int(max_beta/100)*100

# %%
theoretical = [special.erf(vi/(max_beta*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v)")
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for NY 2014-2017 (k=79)")
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
plt.legend()
print("beta = %.3f" % (max_beta))
# Out:
# beta = 130600.000

# %%
print("k = %d" % (len(df2)))

greatest_diff = 1
test_stat = special.kolmogi(0.05)/np.sqrt(k)
print("test_stat at this k = %.5f" % (test_stat))

beta1 = max_beta

while greatest_diff > test_stat:
    theoretical = [special.erf(vi/(beta1*np.sqrt(2))) for vi in v]

    Mb_index = -1
    greatest_diff = 0
    for i, vi in enumerate(v):
        vb =  ratios2[i]-theoretical[i]
        if vb > greatest_diff:
            greatest_diff = vb
            Mb_index = i

    if greatest_diff > test_stat:
        print("\nAt the point of maximum difference with beta = %d:" % (beta1))
        print("P(|d_i|<v) = %.4f" % (ratios2[Mb_index]))
        print("P(|N(0,max_beta^2)|<v) = %.4f" % (theoretical[Mb_index]))
        print("Difference = %.4f" % (greatest_diff))
        #print("beta at this point = %.3f" % (beta[Mb_index]))
        #print(greatest_diff > test_stat)

        print("\n\n")
        beta1 = beta1 - 10000
# Out:
# k = 1233
# test_stat at this k = 0.03868
#
# At the point of maximum difference with beta = 130600:
# P(|d_i|<v) = 0.8273
# P(|N(0,max_beta^2)|<v) = 0.2522
# Difference = 0.5750
#
#
#
#
# At the point of maximum difference with beta = 120600:
# P(|d_i|<v) = 0.8273
# P(|N(0,max_beta^2)|<v) = 0.2723
# Difference = 0.5549
#
#
#
#
# At the point of maximum difference with beta = 110600:
# P(|d_i|<v) = 0.8273
# P(|N(0,max_beta^2)|<v) = 0.2959
# Difference = 0.5314
#
#
#
#
# At the point of maximum difference with beta = 100600:
# P(|d_i|<v) = 0.8054
# P(|N(0,max_beta^2)|<v) = 0.3000
# Difference = 0.5053
#
#
#
#
# At the point of maximum difference with beta = 90600:
# P(|d_i|<v) = 0.7032
# P(|N(0,max_beta^2)|<v) = 0.2246
# Difference = 0.4786
#
#
#
#
# At the point of maximum difference with beta = 80600:
# P(|d_i|<v) = 0.7032
# P(|N(0,max_beta^2)|<v) = 0.2515
# Difference = 0.4516
#
#
#
#
# At the point of maximum difference with beta = 70600:
# P(|d_i|<v) = 0.7032
# P(|N(0,max_beta^2)|<v) = 0.2857
# Difference = 0.4175
#
#
#
#
# At the point of maximum difference with beta = 60600:
# P(|d_i|<v) = 0.7032
# P(|N(0,max_beta^2)|<v) = 0.3302
# Difference = 0.3729
#
#
#
#
# At the point of maximum difference with beta = 50600:
# P(|d_i|<v) = 0.7032
# P(|N(0,max_beta^2)|<v) = 0.3905
# Difference = 0.3127
#
#
#
#
# At the point of maximum difference with beta = 40600:
# P(|d_i|<v) = 0.6934
# P(|N(0,max_beta^2)|<v) = 0.4652
# Difference = 0.2282
#
#
#
#
# At the point of maximum difference with beta = 30600:
# P(|d_i|<v) = 0.4201
# P(|N(0,max_beta^2)|<v) = 0.2804
# Difference = 0.1397

# %%
print("k = %d" % (len(df2)))

greatest_diff = 1
test_stat = special.kolmogi(0.05)/np.sqrt(k)
print("test_stat at this k = %.5f" % (test_stat))

beta1 = beta1 + 10000

while greatest_diff > test_stat:
    theoretical = [special.erf(vi/(beta1*np.sqrt(2))) for vi in v]

    Mb_index = -1
    greatest_diff = 0
    for i, vi in enumerate(v):
        vb =  ratios2[i]-theoretical[i]
        #print(vb)
        if vb > greatest_diff:
            greatest_diff = abs(vb)
            Mb_index = i

    if greatest_diff > test_stat:
        print("\nAt the point of maximum difference with beta = %d:" % (beta1))
        print("P(|d_i|<v) = %.4f" % (ratios2[Mb_index]))
        print("P(|N(0,max_beta^2)|<v) = %.4f" % (theoretical[Mb_index]))
        print("Difference = %.4f" % (greatest_diff))
        #print("beta at this point = %.3f" % (beta[Mb_index]))
        #print(greatest_diff > test_stat)

        print("\n\n")
        beta1 = beta1 - 100
# Out:
# k = 1233
# test_stat at this k = 0.03868
#
# At the point of maximum difference with beta = 30600:
# P(|d_i|<v) = 0.4201
# P(|N(0,max_beta^2)|<v) = 0.2804
# Difference = 0.1397
#
#
#
#
# At the point of maximum difference with beta = 30500:
# P(|d_i|<v) = 0.4201
# P(|N(0,max_beta^2)|<v) = 0.2813
# Difference = 0.1389
#
#
#
#
# At the point of maximum difference with beta = 30400:
# P(|d_i|<v) = 0.4201
# P(|N(0,max_beta^2)|<v) = 0.2821
# Difference = 0.1380
#
#
#
#
# At the point of maximum difference with beta = 30300:
# P(|d_i|<v) = 0.4201
# P(|N(0,max_beta^2)|<v) = 0.2830
# Difference = 0.1371
#
#
#
#
# At the point of maximum difference with beta = 30200:
# P(|d_i|<v) = 0.4201
# P(|N(0,max_beta^2)|<v) = 0.2839
# Difference = 0.1362
#
#
#
#
# At the point of maximum difference with beta = 30100:
# P(|d_i|<v) = 0.4201
# P(|N(0,max_beta^2)|<v) = 0.2848
# Difference = 0.1353
#
#
#
#
# At the point of maximum difference with beta = 30000:
# P(|d_i|<v) = 0.4201
# P(|N(0,max_beta^2)|<v) = 0.2857
# Difference = 0.1344
#
#
#
#
# At the point of maximum difference with beta = 29900:
# P(|d_i|<v) = 0.4201
# P(|N(0,max_beta^2)|<v) = 0.2867
# Difference = 0.1335
#
#
#
#
# At the point of maximum difference with beta = 29800:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2713
# Difference = 0.1325
#
#
#
#
# At the point of maximum difference with beta = 29700:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2722
# Difference = 0.1317
#
#
#
#
# At the point of maximum difference with beta = 29600:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2731
# Difference = 0.1308
#
#
#
#
# At the point of maximum difference with beta = 29500:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2740
# Difference = 0.1299
#
#
#
#
# At the point of maximum difference with beta = 29400:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2749
# Difference = 0.1290
#
#
#
#
# At the point of maximum difference with beta = 29300:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2758
# Difference = 0.1281
#
#
#
#
# At the point of maximum difference with beta = 29200:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2767
# Difference = 0.1272
#
#
#
#
# At the point of maximum difference with beta = 29100:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2776
# Difference = 0.1263
#
#
#
#
# At the point of maximum difference with beta = 29000:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2785
# Difference = 0.1254
#
#
#
#
# At the point of maximum difference with beta = 28900:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2794
# Difference = 0.1244
#
#
#
#
# At the point of maximum difference with beta = 28800:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2804
# Difference = 0.1235
#
#
#
#
# At the point of maximum difference with beta = 28700:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2813
# Difference = 0.1226
#
#
#
#
# At the point of maximum difference with beta = 28600:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2823
# Difference = 0.1216
#
#
#
#
# At the point of maximum difference with beta = 28500:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2832
# Difference = 0.1207
#
#
#
#
# At the point of maximum difference with beta = 28400:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2842
# Difference = 0.1197
#
#
#
#
# At the point of maximum difference with beta = 28300:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2851
# Difference = 0.1188
#
#
#
#
# At the point of maximum difference with beta = 28200:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2861
# Difference = 0.1178
#
#
#
#
# At the point of maximum difference with beta = 28100:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2871
# Difference = 0.1168
#
#
#
#
# At the point of maximum difference with beta = 28000:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2880
# Difference = 0.1159
#
#
#
#
# At the point of maximum difference with beta = 27900:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2890
# Difference = 0.1149
#
#
#
#
# At the point of maximum difference with beta = 27800:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2900
# Difference = 0.1139
#
#
#
#
# At the point of maximum difference with beta = 27700:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2910
# Difference = 0.1129
#
#
#
#
# At the point of maximum difference with beta = 27600:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2920
# Difference = 0.1119
#
#
#
#
# At the point of maximum difference with beta = 27500:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2930
# Difference = 0.1109
#
#
#
#
# At the point of maximum difference with beta = 27400:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2941
# Difference = 0.1098
#
#
#
#
# At the point of maximum difference with beta = 27300:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2951
# Difference = 0.1088
#
#
#
#
# At the point of maximum difference with beta = 27200:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2961
# Difference = 0.1078
#
#
#
#
# At the point of maximum difference with beta = 27100:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2972
# Difference = 0.1067
#
#
#
#
# At the point of maximum difference with beta = 27000:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2982
# Difference = 0.1057
#
#
#
#
# At the point of maximum difference with beta = 26900:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.2993
# Difference = 0.1046
#
#
#
#
# At the point of maximum difference with beta = 26800:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3003
# Difference = 0.1036
#
#
#
#
# At the point of maximum difference with beta = 26700:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3014
# Difference = 0.1025
#
#
#
#
# At the point of maximum difference with beta = 26600:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3025
# Difference = 0.1014
#
#
#
#
# At the point of maximum difference with beta = 26500:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3036
# Difference = 0.1003
#
#
#
#
# At the point of maximum difference with beta = 26400:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3046
# Difference = 0.0993
#
#
#
#
# At the point of maximum difference with beta = 26300:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3057
# Difference = 0.0982
#
#
#
#
# At the point of maximum difference with beta = 26200:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3069
# Difference = 0.0970
#
#
#
#
# At the point of maximum difference with beta = 26100:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3080
# Difference = 0.0959
#
#
#
#
# At the point of maximum difference with beta = 26000:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3091
# Difference = 0.0948
#
#
#
#
# At the point of maximum difference with beta = 25900:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3102
# Difference = 0.0937
#
#
#
#
# At the point of maximum difference with beta = 25800:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3114
# Difference = 0.0925
#
#
#
#
# At the point of maximum difference with beta = 25700:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3125
# Difference = 0.0914
#
#
#
#
# At the point of maximum difference with beta = 25600:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3137
# Difference = 0.0902
#
#
#
#
# At the point of maximum difference with beta = 25500:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3148
# Difference = 0.0891
#
#
#
#
# At the point of maximum difference with beta = 25400:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3160
# Difference = 0.0879
#
#
#
#
# At the point of maximum difference with beta = 25300:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3172
# Difference = 0.0867
#
#
#
#
# At the point of maximum difference with beta = 25200:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3184
# Difference = 0.0855
#
#
#
#
# At the point of maximum difference with beta = 25100:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3196
# Difference = 0.0843
#
#
#
#
# At the point of maximum difference with beta = 25000:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3208
# Difference = 0.0831
#
#
#
#
# At the point of maximum difference with beta = 24900:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3220
# Difference = 0.0819
#
#
#
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3232
# Difference = 0.0807
#
#
#
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.4039
# P(|N(0,max_beta^2)|<v) = 0.3245
# Difference = 0.0794
#
#
#
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2672
# Difference = 0.0783
#
#
#
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2683
# Difference = 0.0772
#
#
#
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2693
# Difference = 0.0762
#
#
#
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2704
# Difference = 0.0751
#
#
#
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2715
# Difference = 0.0740
#
#
#
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2726
# Difference = 0.0729
#
#
#
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2737
# Difference = 0.0718
#
#
#
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2748
# Difference = 0.0707
#
#
#
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2759
# Difference = 0.0696
#
#
#
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2770
# Difference = 0.0685
#
#
#
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2781
# Difference = 0.0674
#
#
#
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2792
# Difference = 0.0663
#
#
#
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2804
# Difference = 0.0651
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2815
# Difference = 0.0640
#
#
#
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2827
# Difference = 0.0628
#
#
#
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2839
# Difference = 0.0616
#
#
#
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2850
# Difference = 0.0605
#
#
#
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2862
# Difference = 0.0593
#
#
#
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2874
# Difference = 0.0581
#
#
#
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2886
# Difference = 0.0569
#
#
#
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2899
# Difference = 0.0556
#
#
#
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2911
# Difference = 0.0544
#
#
#
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2923
# Difference = 0.0532
#
#
#
#
# At the point of maximum difference with beta = 22300:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2936
# Difference = 0.0519
#
#
#
#
# At the point of maximum difference with beta = 22200:
# P(|d_i|<v) = 0.3455
# P(|N(0,max_beta^2)|<v) = 0.2948
# Difference = 0.0507
#
#
#
#
# At the point of maximum difference with beta = 22100:
# P(|d_i|<v) = 0.3017
# P(|N(0,max_beta^2)|<v) = 0.2522
# Difference = 0.0495
#
#
#
#
# At the point of maximum difference with beta = 22000:
# P(|d_i|<v) = 0.3017
# P(|N(0,max_beta^2)|<v) = 0.2534
# Difference = 0.0483
#
#
#
#
# At the point of maximum difference with beta = 21900:
# P(|d_i|<v) = 0.3017
# P(|N(0,max_beta^2)|<v) = 0.2545
# Difference = 0.0472
#
#
#
#
# At the point of maximum difference with beta = 21800:
# P(|d_i|<v) = 0.3017
# P(|N(0,max_beta^2)|<v) = 0.2556
# Difference = 0.0461
#
#
#
#
# At the point of maximum difference with beta = 21700:
# P(|d_i|<v) = 0.3017
# P(|N(0,max_beta^2)|<v) = 0.2567
# Difference = 0.0450
#
#
#
#
# At the point of maximum difference with beta = 21600:
# P(|d_i|<v) = 0.3017
# P(|N(0,max_beta^2)|<v) = 0.2579
# Difference = 0.0438
#
#
#
#
# At the point of maximum difference with beta = 21500:
# P(|d_i|<v) = 0.3017
# P(|N(0,max_beta^2)|<v) = 0.2590
# Difference = 0.0427
#
#
#
#
# At the point of maximum difference with beta = 21400:
# P(|d_i|<v) = 0.3017
# P(|N(0,max_beta^2)|<v) = 0.2602
# Difference = 0.0415
#
#
#
#
# At the point of maximum difference with beta = 21300:
# P(|d_i|<v) = 0.3017
# P(|N(0,max_beta^2)|<v) = 0.2614
# Difference = 0.0403
#
#
#
#
# At the point of maximum difference with beta = 21200:
# P(|d_i|<v) = 0.3017
# P(|N(0,max_beta^2)|<v) = 0.2626
# Difference = 0.0391

# %%
beta1 = beta1+100

#this_nb_state = "CAWINY"
theoretical = [special.erf(vi/(beta1*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) beta=%d" % (beta1))
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (this_nb_state, k))
plt.axvline(x=v[Mb_index], color='r', linestyle='--', label="Point of max difference")
plt.legend()
#print("beta = %.3f" % (max_beta))

# %%
print("k = %d" % (len(df2)))
print("test_stat at this k = %.5f" % (test_stat))
# Out:
# k = 1233
# test_stat at this k = 0.03868

# %%
max(abs(df2))
# Out:
# 645485.9232224716

# %%
def run_stat_test(beta, values):
    above_2_count = 0
    for i in range(len(values)):
        if abs(values[i]) > 2*beta:
            above_2_count += 1
    p_above_2 = 1 - special.erf(np.sqrt(2))
    print("Number of above 2: %d" % (above_2_count))
    print("Proportion of above 2: %.3f" % (above_2_count / len(values)))
    print("P value = %.6f" % (1- binom(above_2_count, len(values), p_above_2)))
    
run_stat_test(beta1, df2.values)
# Out:
# Number of above 2: 212
# Proportion of above 2: 0.172
# P value = 0.000000

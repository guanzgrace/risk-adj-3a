# %%
# %run StatTest2_WithSimulation_Setup.ipynb

# %%
data2014 = pd.read_csv("Our_Dataset/2014dataset.csv")
data2015 = pd.read_csv("Our_Dataset/2015dataset.csv")
data2016 = pd.read_csv("Our_Dataset/2016dataset.csv")
data2017 = pd.read_csv("Our_Dataset/2017dataset.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,52,323,649,882,932,1092,1202) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,57,204,341,376,377,396,430,431,928,944,1006,1013,1151,1160,1169,1179,1411) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,17,163,355,406,702,835,847,1083,1156,1183,1185,1200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Create the labels.
# By index:
# label 2 is transfers
# label 3 is premiums
# label 4 is costs
# label 5 is member months
# label 6 is reinsurance (individual group only)

ind_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                  "HHS RISK ADJUSTMENT TRANSFER AMOUNT (INDIVIDUAL MARKET, INCLUDING CATASTROPHIC)",
                  "1.1Directpremiumwritten2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "2.16Totalincurredclaims2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "7.4Membermonths2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "STATE", "REINSURANCE PAYMENT AMOUNT (OR NOT ELIGIBLE)"] # no more reinsurance as of 2017
ind_labels_15 = [label.replace('15', '16') for label in ind_labels_14]
ind_labels_16 = [label.replace('15', '17') for label in ind_labels_14]
ind_labels_17 = [label.replace('15', '18') for label in ind_labels_14][:-1]

sg_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                 "HHS RISK ADJUSTMENT TRANSFERS AMOUNT (SMALL GROUP MARKET)",
                  "1.1Directpremiumwritten7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "2.16Totalincurredclaims7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "7.4Membermonths7HealthInsuranceSMALLGROUPTotalasof3/31/15", "STATE"]
sg_labels_15 = [label.replace('15', '16') for label in sg_labels_14]
sg_labels_16 = [label.replace('15', '17') for label in sg_labels_14]
sg_labels_17 = [label.replace('15', '18') for label in sg_labels_14]

# %%
# Filter the data to include only the fields we want

ind_data_14 = data2014[ind_labels_14].dropna()
ind_data_15 = data2015[ind_labels_15].dropna()
ind_data_16 = data2016[ind_labels_16].dropna()
ind_data_17 = data2017[ind_labels_17].dropna()
sg_data_14 = data2014[sg_labels_14].dropna()
sg_data_15 = data2015[sg_labels_15].dropna()
sg_data_16 = data2016[sg_labels_16].dropna()
sg_data_17 = data2017[sg_labels_17].dropna()

# %%
# Drop companies with <2000 MM
ind_data_14 = ind_data_14.where(ind_data_14[ind_labels_14[5]] > 2000).dropna()
ind_data_15 = ind_data_15.where(ind_data_15[ind_labels_15[5]] > 2000).dropna()
ind_data_16 = ind_data_16.where(ind_data_16[ind_labels_16[5]] > 2000).dropna()
ind_data_17 = ind_data_17.where(ind_data_17[ind_labels_17[5]] > 2000).dropna()
sg_data_14 = sg_data_14.where(sg_data_14[sg_labels_14[5]] > 2000).dropna()
sg_data_15 = sg_data_15.where(sg_data_15[sg_labels_15[5]] > 2000).dropna()
sg_data_16 = sg_data_16.where(sg_data_16[sg_labels_16[5]] > 2000).dropna()
sg_data_17 = sg_data_17.where(sg_data_17[sg_labels_17[5]] > 2000).dropna()

# %%
# Calculate transfers, premiums, costs, and reinsurance (if individual group) per member month
def calculate_pmm(df, df_labels, group):
    df["MM"] = df[df_labels[5]]
    df["Transfers"] = df[df_labels[2]]
    df["TotalCosts"] = abs(df[df_labels[4]])
    df["Enrollees"] = df["MM"] / 12
    df["TransfersPerEnrollee"] = df["Transfers"] / df["Enrollees"]
    df["TransfersPerSqrtEnrollee"] = df["Transfers"] / np.sqrt(df["Enrollees"])
    df["LogEnrollees"] = np.log(df["Enrollees"])
    df["LogTransfers"] = np.log(df["Transfers"]**2 + 1)
    df["TransfersPMM"] = df[df_labels[2]] / df[df_labels[5]]
    df["PremiumsPMM"] = abs(df[df_labels[3]] / df[df_labels[5]])
    df["CostsPMM"] = abs(df[df_labels[4]] / df[df_labels[5]])
    if group == "i":
        df["ReinsurancePMM"] = df[df_labels[7]] / df[df_labels[5]]
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"] + df["ReinsurancePMM"]
        #df["PremMinusCostsPlusReinsurancePMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["ReinsurancePMM"]
    elif group == "sg":
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["PremMinusCostsPMM"] = df["PremiumsPMM"] - df["CostsPMM"]
    df["PremMinusCostsPlusTransfersPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["SicknessPMM"] = df["CostsPMM"] - df["PremiumsPMM"]
    average_sickness = np.mean(df["SicknessPMM"])
    df["ExcessSicknessPMM"] = df["SicknessPMM"] - average_sickness
    return df

ind_data_14 = calculate_pmm(ind_data_14, ind_labels_14, "i")
ind_data_15 = calculate_pmm(ind_data_15, ind_labels_15, "i")
ind_data_16 = calculate_pmm(ind_data_16, ind_labels_16, "i")
ind_data_17 = calculate_pmm(ind_data_17, ind_labels_17, "sg")
sg_data_14 = calculate_pmm(sg_data_14, sg_labels_14, "sg")
sg_data_15 = calculate_pmm(sg_data_15, sg_labels_15, "sg")
sg_data_16 = calculate_pmm(sg_data_16, sg_labels_16, "sg")
sg_data_17 = calculate_pmm(sg_data_17, sg_labels_17, "sg")

# %%
# Combine the dataframes by left merging

ind_data = ind_data_14.merge(ind_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(ind_data_16, on='HIOS ID', how='outer').merge(ind_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
# Do the same thing for small group

sg_data = sg_data_14.merge(sg_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(sg_data_16, on='HIOS ID', how='outer').merge(sg_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
states = ['MT', 'IN', 'CA', 'HI', 'ND', 'MD', 'TN', 'SC', 'AL', 'RI', 'AK', 'NY',
          'KY', 'NJ', 'KS', 'WI', 'ID', 'LA', 'MN', 'MS', 'IA', 'AR', 'WV', 'FL', 'MO']
dfs = [sg_data_14, sg_data_15, sg_data_16, sg_data_17]

# %%
dfs_new = normalize_empirical_data(dfs, states)
# Out:
# 259
# 256
# 226
# 199
# MT 14 Ratio is 1.106
# IN 14 Ratio is 1.177
# CA 14 Ratio is 1.077
# HI 14 Ratio is 1.097
# ND 14 Ratio is 1.122
# MD 14 Ratio is 1.156
# TN 14 Ratio is 1.351
# SC 14 Ratio is 1.041
# AL 14 Ratio is 1.079
# RI 14 Ratio is 0.942
# AK 14 Ratio is 0.712
# NY 14 Ratio is 0.909
# KY 14 Ratio is 1.297
# NJ 14 Ratio is 1.095
# KS 14 Ratio is 1.300
# WI 14 Ratio is 1.053
# ID 14 Ratio is 1.386
# LA 14 Ratio is 1.106
# MN 14 Ratio is 1.103
# MS 14 Ratio is 1.270
# IA 14 Ratio is 1.231
# AR 14 Ratio is 1.376
# WV 14 Ratio is 0.964
# FL 14 Ratio is 1.120
# MO 14 Ratio is 1.320
# MT 15 Ratio is 1.027
# IN 15 Ratio is 1.099
# CA 15 Ratio is 1.043
# HI 15 Ratio is 1.014
# ND 15 Ratio is 1.023
# MD 15 Ratio is 1.185
# TN 15 Ratio is 1.293
# SC 15 Ratio is 0.986
# AL 15 Ratio is 1.024
# RI 15 Ratio is 1.005
# AK 15 Ratio is 0.662
# NY 15 Ratio is 0.837
# KY 15 Ratio is 1.212
# NJ 15 Ratio is 0.942
# KS 15 Ratio is 1.147
# WI 15 Ratio is 1.026
# ID 15 Ratio is 1.337
# LA 15 Ratio is 1.008
# MN 15 Ratio is 1.079
# MS 15 Ratio is 1.218
# IA 15 Ratio is 1.189
# AR 15 Ratio is 1.314
# WV 15 Ratio is 0.982
# FL 15 Ratio is 1.084
# MO 15 Ratio is 1.197
# MT 16 Ratio is 1.072
# IN 16 Ratio is 1.008
# CA 16 Ratio is 0.982
# HI 16 Ratio is 0.975
# ND 16 Ratio is 0.988
# MD 16 Ratio is 1.135
# TN 16 Ratio is 1.169
# SC 16 Ratio is 0.929
# AL 16 Ratio is 0.999
# RI 16 Ratio is 0.922
# AK 16 Ratio is 0.598
# NY 16 Ratio is 0.805
# KY 16 Ratio is 1.117
# NJ 16 Ratio is 0.861
# KS 16 Ratio is 1.063
# WI 16 Ratio is 0.984
# ID 16 Ratio is 1.229
# LA 16 Ratio is 0.991
# MN 16 Ratio is 0.982
# MS 16 Ratio is 1.152
# IA 16 Ratio is 1.136
# AR 16 Ratio is 1.219
# WV 16 Ratio is 0.887
# FL 16 Ratio is 1.038
# MO 16 Ratio is 1.116
# MT 17 Ratio is 1.009
# IN 17 Ratio is 0.965
# CA 17 Ratio is 0.948
# HI 17 Ratio is 0.912
# ND 17 Ratio is 0.985
# MD 17 Ratio is 1.074
# TN 17 Ratio is 1.177
# SC 17 Ratio is 0.891
# AL 17 Ratio is 0.993
# RI 17 Ratio is 0.861
# AK 17 Ratio is 0.607
# NY 17 Ratio is 0.731
# KY 17 Ratio is 1.036
# NJ 17 Ratio is 0.795
# KS 17 Ratio is 0.952
# WI 17 Ratio is 0.938
# ID 17 Ratio is 1.194
# LA 17 Ratio is 0.963
# MN 17 Ratio is 0.929
# MS 17 Ratio is 1.087
# IA 17 Ratio is 1.173
# AR 17 Ratio is 1.154
# WV 17 Ratio is 0.872
# FL 17 Ratio is 0.977
# MO 17 Ratio is 1.077
# Empirical Transfers Sum = 5301487160.835

# %%
mm_total = 0
e_ti_total = 0
for adf in dfs_new:
    mm_total = mm_total + sum(adf["MM"])
    e_ti_total = e_ti_total + sum(abs(adf["TransfersNormalized"]))
print(mm_total)
print(e_ti_total)
# Out:
# 348487745.5636
# 5301487160.835426

# %%
for df_temp in dfs_new:
    df_temp["TransfersNormalizedPerSqrtEnrollee"] = df_temp["TransfersNormalized"] / np.sqrt(df_temp["Enrollees"])

# %%
df2 = create_df2(states, dfs_new, "TransfersNormalizedPerSqrtEnrollee")

# %%
k = len(df2)
v = np.linspace(0, max(abs(df2)), 10000)
v = v[1:len(v)]

ratios = [ratio_list(df2, vi) for vi in v]
#print(ratios)
begin_p = 5/k
end_p = 1-begin_p
start_index = 0
end_index = 0
for index, ratio2 in enumerate(ratios):
    if ratio2 >= begin_p:
        start_index = index
        break
    
for index, ratio2 in enumerate(ratios):
    if ratio2 > end_p:
        end_index = index
        break

if end_index == 0:
    end_index = len(v) - 1
    
v = v[start_index:end_index]

ratios2 = ratios[start_index:end_index]
multiplier = [np.sqrt(2)/vi for vi in v]
#plt.plot(v, ratios2)
#plt.plot(v, multiplier)

# %%
y = [multiplier[i] * special.erfinv(ratio2) for i, ratio2 in enumerate(ratios2)]
#plt.plot(v, y)
#plt.title("1/beta vs. v")
beta = [1/yi for yi in y]
#plt.plot(v, beta)
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
#plt.title("beta vs. v")

# %%
# Finding the minimum beta
# Whenever we reject a beta, we reject all betas greater than that,
# so keep pushing beta smaller until we reach max_difference == test_statistic
# Run test for larger data sizes (combining states, years)

# %%
max_beta=max(beta)
max_beta = int(max_beta/100)*100

# %%
state_label = "All States"

# %%
theoretical = [special.erf(vi/(max_beta*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v)")
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (state_label, len(df2)))
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
plt.legend()
print("beta = %.3f" % (max_beta))
# Out:
# beta = 116500.000

# %%
beta1, Mb_index = run_test_against_theoretical(df2, max_beta, ratios2)
# Out:
# k = 936
# test_stat at this k = 0.04439
#
# At the point of maximum difference with beta = 116500:
# P(|d_i|<v) = 0.7895
# P(|N(0,max_beta^2)|<v) = 0.2034
# Difference = 0.5861
#
#
#
#
# At the point of maximum difference with beta = 106500:
# P(|d_i|<v) = 0.7895
# P(|N(0,max_beta^2)|<v) = 0.2220
# Difference = 0.5675
#
#
#
#
# At the point of maximum difference with beta = 96500:
# P(|d_i|<v) = 0.7895
# P(|N(0,max_beta^2)|<v) = 0.2443
# Difference = 0.5452
#
#
#
#
# At the point of maximum difference with beta = 86500:
# P(|d_i|<v) = 0.7895
# P(|N(0,max_beta^2)|<v) = 0.2715
# Difference = 0.5180
#
#
#
#
# At the point of maximum difference with beta = 76500:
# P(|d_i|<v) = 0.7895
# P(|N(0,max_beta^2)|<v) = 0.3053
# Difference = 0.4842
#
#
#
#
# At the point of maximum difference with beta = 66500:
# P(|d_i|<v) = 0.7105
# P(|N(0,max_beta^2)|<v) = 0.2663
# Difference = 0.4441
#
#
#
#
# At the point of maximum difference with beta = 56500:
# P(|d_i|<v) = 0.7105
# P(|N(0,max_beta^2)|<v) = 0.3112
# Difference = 0.3993
#
#
#
#
# At the point of maximum difference with beta = 46500:
# P(|d_i|<v) = 0.7105
# P(|N(0,max_beta^2)|<v) = 0.3735
# Difference = 0.3370
#
#
#
#
# At the point of maximum difference with beta = 36500:
# P(|d_i|<v) = 0.5438
# P(|N(0,max_beta^2)|<v) = 0.2753
# Difference = 0.2685
#
#
#
#
# At the point of maximum difference with beta = 26500:
# P(|d_i|<v) = 0.4947
# P(|N(0,max_beta^2)|<v) = 0.3089
# Difference = 0.1857
#
#
#
#
# At the point of maximum difference with beta = 16500:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2466
# Difference = 0.0707
#
#
#
#
# At the point of maximum difference with beta = 16500:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2466
# Difference = 0.0707
#
#
#
#
# At the point of maximum difference with beta = 16400:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2481
# Difference = 0.0692
#
#
#
#
# At the point of maximum difference with beta = 16300:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2496
# Difference = 0.0677
#
#
#
#
# At the point of maximum difference with beta = 16200:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1715
# Difference = 0.0667
#
#
#
#
# At the point of maximum difference with beta = 16100:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1726
# Difference = 0.0657
#
#
#
#
# At the point of maximum difference with beta = 16000:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1737
# Difference = 0.0646
#
#
#
#
# At the point of maximum difference with beta = 15900:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1747
# Difference = 0.0635
#
#
#
#
# At the point of maximum difference with beta = 15800:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1758
# Difference = 0.0624
#
#
#
#
# At the point of maximum difference with beta = 15700:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1769
# Difference = 0.0613
#
#
#
#
# At the point of maximum difference with beta = 15600:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1780
# Difference = 0.0602
#
#
#
#
# At the point of maximum difference with beta = 15500:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1792
# Difference = 0.0591
#
#
#
#
# At the point of maximum difference with beta = 15400:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1803
# Difference = 0.0579
#
#
#
#
# At the point of maximum difference with beta = 15300:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1815
# Difference = 0.0568
#
#
#
#
# At the point of maximum difference with beta = 15200:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1826
# Difference = 0.0556
#
#
#
#
# At the point of maximum difference with beta = 15100:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1838
# Difference = 0.0544
#
#
#
#
# At the point of maximum difference with beta = 15000:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1850
# Difference = 0.0532
#
#
#
#
# At the point of maximum difference with beta = 14900:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1863
# Difference = 0.0520
#
#
#
#
# At the point of maximum difference with beta = 14800:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0930
# Difference = 0.0513
#
#
#
#
# At the point of maximum difference with beta = 14700:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0936
# Difference = 0.0506
#
#
#
#
# At the point of maximum difference with beta = 14600:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0942
# Difference = 0.0500
#
#
#
#
# At the point of maximum difference with beta = 14500:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0949
# Difference = 0.0494
#
#
#
#
# At the point of maximum difference with beta = 14400:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0955
# Difference = 0.0487
#
#
#
#
# At the point of maximum difference with beta = 14300:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0962
# Difference = 0.0480
#
#
#
#
# At the point of maximum difference with beta = 14200:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0969
# Difference = 0.0474
#
#
#
#
# At the point of maximum difference with beta = 14100:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0975
# Difference = 0.0467
#
#
#
#
# At the point of maximum difference with beta = 14000:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0982
# Difference = 0.0460
#
#
#
#
# At the point of maximum difference with beta = 13900:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0989
# Difference = 0.0453
#
#
#
#
# At the point of maximum difference with beta = 13800:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0997
# Difference = 0.0446

# %%
beta1 = beta1+100

theoretical = [special.erf(vi/(beta1*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) beta=%d" % (beta1))
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (state_label, len(df2)))
plt.axvline(x=v[Mb_index], color='r', linestyle='--', label="Point of max difference")
plt.legend()
#plt.xlim(0, 50000)
#print("beta = %.3f" % (max_beta))

# %%
run_binom_stat_test2(beta1, df2.values)
# Out:
# Beta (=std): 13800
# Number of T/sqrt(n) above 2 stds: 228
# Proportion of T/sqrt(n) above 2 stds: 0.244
# P value = 0.000000

# %%
#df3 = create_df3(states, dfs_new)

# %%
ratios_c, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta1 - 10000)
ratios_c2, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta1)
ratios_c3, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta1 + 10000)
# Out:
# Sum sqrt(a) = 100535.487
# Sum sqrt(a) = 100535.487
# Sum sqrt(a) = 100535.487

# %%
theoretical = [special.erf(vi/(beta1*np.sqrt(2))) for vi in v]

plt.figure(figsize=(10, 7))
plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) with beta = %d" % (beta1))
plt.plot(v, ratios2, label="P(|d_i|<v) = empirical distribution")
plt.plot(v, ratios_c, label="Simulation with es = %d, 5 times" % (beta1 - 10000))
plt.plot(v, ratios_c2, label="Simulation with es = %d, 5 times" % (beta1))
plt.plot(v, ratios_c3, label="Simulation with es = %d, 5 times" % (beta1 + 10000))
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s (k=%d)" % (state_label, len(df2)))
plt.legend()

# %%
beta1, _ = run_test_against_simulation_adjust_for_imbalances(states, dfs_new, beta1, ratios2)
# Out:
# k = 936
# test_stat at this k = 0.04439
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 13800:
# P(|d_i|<v) = 0.1154
# P(|N(0,max_beta^2)|<v) = 0.0821
# Difference = 0.0333 NOT > test_stat
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2036
# Difference = 0.1137
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2031
# Difference = 0.1142
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2057
# Difference = 0.1116
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.1995
# Difference = 0.1178
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.3547
# P(|N(0,max_beta^2)|<v) = 0.2496
# Difference = 0.1051
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2011
# Difference = 0.1162
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2058
# Difference = 0.1115
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2065
# Difference = 0.1108
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2047
# Difference = 0.1126
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2060
# Difference = 0.1113
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2091
# Difference = 0.1082
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2126
# Difference = 0.1047
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.3120
# P(|N(0,max_beta^2)|<v) = 0.2105
# Difference = 0.1015
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2173
# Difference = 0.1000
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2168
# Difference = 0.1005
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 22300:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2224
# Difference = 0.0949
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 22200:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2120
# Difference = 0.1053
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 22100:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2197
# Difference = 0.0976
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 22000:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2171
# Difference = 0.1002
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 21900:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2138
# Difference = 0.1035
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 21800:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2207
# Difference = 0.0967
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 21700:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2219
# Difference = 0.0954
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 21600:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2254
# Difference = 0.0919
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 21500:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2167
# Difference = 0.1006
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 21400:
# P(|d_i|<v) = 0.3120
# P(|N(0,max_beta^2)|<v) = 0.2210
# Difference = 0.0910
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 21300:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2237
# Difference = 0.0936
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 21200:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2254
# Difference = 0.0919
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2233
# Difference = 0.0940
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2263
# Difference = 0.0910
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2244
# Difference = 0.0929
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2293
# Difference = 0.0880
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2317
# Difference = 0.0856
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2330
# Difference = 0.0843
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 20500:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2287
# Difference = 0.0886
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 20400:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2355
# Difference = 0.0818
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 20300:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2400
# Difference = 0.0773
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 20200:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2327
# Difference = 0.0846
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 20100:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2377
# Difference = 0.0796
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 20000:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2362
# Difference = 0.0811
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 19900:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2363
# Difference = 0.0810
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 19800:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2410
# Difference = 0.0763
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 19700:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2411
# Difference = 0.0762
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 19600:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2390
# Difference = 0.0783
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 19500:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2426
# Difference = 0.0747
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 19400:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2452
# Difference = 0.0722
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 19300:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2417
# Difference = 0.0756
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 19200:
# P(|d_i|<v) = 0.3120
# P(|N(0,max_beta^2)|<v) = 0.2398
# Difference = 0.0722
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 19100:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2473
# Difference = 0.0700
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 19000:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1682
# Difference = 0.0701
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 18900:
# P(|d_i|<v) = 0.3120
# P(|N(0,max_beta^2)|<v) = 0.2448
# Difference = 0.0672
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 18800:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2467
# Difference = 0.0707
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 18700:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2556
# Difference = 0.0617
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 18600:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2490
# Difference = 0.0683
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 18500:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2544
# Difference = 0.0629
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 18400:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2505
# Difference = 0.0668
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 18300:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1827
# Difference = 0.0556
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 18200:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1801
# Difference = 0.0582
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 18100:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1808
# Difference = 0.0574
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 18000:
# P(|d_i|<v) = 0.3173
# P(|N(0,max_beta^2)|<v) = 0.2579
# Difference = 0.0594
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 17900:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1793
# Difference = 0.0589
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 17800:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1765
# Difference = 0.0618
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 17700:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1806
# Difference = 0.0577
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 17600:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1863
# Difference = 0.0520
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 17500:
# P(|d_i|<v) = 0.1410
# P(|N(0,max_beta^2)|<v) = 0.0900
# Difference = 0.0510
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 17400:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0925
# Difference = 0.0517
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 17300:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0948
# Difference = 0.0494
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 17200:
# P(|d_i|<v) = 0.1667
# P(|N(0,max_beta^2)|<v) = 0.1142
# Difference = 0.0524
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 17100:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0982
# Difference = 0.0460
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 17000:
# P(|d_i|<v) = 0.2382
# P(|N(0,max_beta^2)|<v) = 0.1892
# Difference = 0.0491
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 16900:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0964
# Difference = 0.0478
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 16800:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0959
# Difference = 0.0483
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 16700:
# P(|d_i|<v) = 0.1667
# P(|N(0,max_beta^2)|<v) = 0.1155
# Difference = 0.0511
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 16600:
# P(|d_i|<v) = 0.1838
# P(|N(0,max_beta^2)|<v) = 0.1350
# Difference = 0.0487
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 16500:
# P(|d_i|<v) = 0.1442
# P(|N(0,max_beta^2)|<v) = 0.0964
# Difference = 0.0479
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 16400:
# P(|d_i|<v) = 0.1410
# P(|N(0,max_beta^2)|<v) = 0.0957
# Difference = 0.0453
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 16300:
# P(|d_i|<v) = 0.1378
# P(|N(0,max_beta^2)|<v) = 0.0920
# Difference = 0.0459
#
#
#
# Sum sqrt(a) = 100535.487
#
# At the point of maximum difference with beta = 16200:
# P(|d_i|<v) = 0.1667
# P(|N(0,max_beta^2)|<v) = 0.1233
# Difference = 0.0434 NOT > test_stat
# E(|X|) = 733161286.557

# %%
run_binom_stat_test2(beta1, df2.values)
# Out:
# Beta (=std): 16200
# Number of T/sqrt(n) above 2 stds: 189
# Proportion of T/sqrt(n) above 2 stds: 0.202
# P value = 0.000000

# %%
# %run StatTest2_WithSimulation_Setup.ipynb
# Out:
# {0: ['ME', 'IL', 'PA', 'GA', 'OK', 'DE', 'WA', 'CT', 'OH', 'VA', 'NE', 'MT', 'IN', 'CA', 'HI', 'ND', 'MD', 'SC', 'RI', 'AK', 'KY', 'WI', 'LA', 'MN', 'MS', 'WV', 'FL'], 1: ['SD', 'IL', 'PA', 'NH', 'NM', 'NV', 'OK', 'UT', 'CT', 'OH', 'VA', 'OR', 'CO', 'IN', 'HI', 'AL', 'RI', 'AK', 'LA', 'MN', 'IA', 'AR', 'WV'], 2: ['MI', 'ME', 'WY', 'DC', 'TX', 'AZ', 'NC', 'WA', 'OR', 'CO', 'MT', 'ND', 'TN', 'SC', 'AL', 'NY', 'KY', 'NJ', 'KS', 'ID', 'IA', 'AR', 'MO'], 3: ['MI', 'SD', 'WY', 'NH', 'DC', 'TX', 'GA', 'AZ', 'NM', 'NC', 'NV', 'DE', 'UT', 'NE', 'CA', 'MD', 'TN', 'NY', 'NJ', 'KS', 'WI', 'ID', 'MS', 'FL', 'MO']}
# {0: ['MI', 'SD', 'WY', 'NH', 'DC', 'TX', 'AZ', 'NM', 'NC', 'NV', 'UT', 'OR', 'CO', 'TN', 'AL', 'NY', 'NJ', 'KS', 'ID', 'IA', 'AR', 'MO'], 1: ['MI', 'ME', 'WY', 'DC', 'TX', 'GA', 'AZ', 'NC', 'DE', 'WA', 'NE', 'MT', 'CA', 'ND', 'MD', 'TN', 'SC', 'NY', 'KY', 'NJ', 'KS', 'WI', 'ID', 'MS', 'FL', 'MO'], 2: ['SD', 'IL', 'PA', 'NH', 'GA', 'NM', 'NV', 'OK', 'DE', 'UT', 'CT', 'OH', 'VA', 'NE', 'IN', 'CA', 'HI', 'MD', 'RI', 'AK', 'WI', 'LA', 'MN', 'MS', 'WV', 'FL'], 3: ['ME', 'IL', 'PA', 'OK', 'WA', 'CT', 'OH', 'VA', 'OR', 'CO', 'MT', 'IN', 'HI', 'ND', 'SC', 'AL', 'RI', 'AK', 'KY', 'LA', 'MN', 'IA', 'AR', 'WV']}

# %%
data2014 = pd.read_csv("Our_Dataset/2014dataset.csv")
data2015 = pd.read_csv("Our_Dataset/2015dataset.csv")
data2016 = pd.read_csv("Our_Dataset/2016dataset.csv")
data2017 = pd.read_csv("Our_Dataset/2017dataset.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,52,323,649,882,932,1092,1202) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,57,204,341,376,377,396,430,431,928,944,1006,1013,1151,1160,1169,1179,1411) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,17,163,355,406,702,835,847,1083,1156,1183,1185,1200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Create the labels.
# By index:
# label 2 is transfers
# label 3 is premiums
# label 4 is costs
# label 5 is member months
# label 6 is reinsurance (individual group only)

ind_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                  "HHS RISK ADJUSTMENT TRANSFER AMOUNT (INDIVIDUAL MARKET, INCLUDING CATASTROPHIC)",
                  "1.1Directpremiumwritten2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "2.16Totalincurredclaims2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "7.4Membermonths2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "STATE", "REINSURANCE PAYMENT AMOUNT (OR NOT ELIGIBLE)"] # no more reinsurance as of 2017
ind_labels_15 = [label.replace('15', '16') for label in ind_labels_14]
ind_labels_16 = [label.replace('15', '17') for label in ind_labels_14]
ind_labels_17 = [label.replace('15', '18') for label in ind_labels_14][:-1]

sg_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                 "HHS RISK ADJUSTMENT TRANSFERS AMOUNT (SMALL GROUP MARKET)",
                  "1.1Directpremiumwritten7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "2.16Totalincurredclaims7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "7.4Membermonths7HealthInsuranceSMALLGROUPTotalasof3/31/15", "STATE"]
sg_labels_15 = [label.replace('15', '16') for label in sg_labels_14]
sg_labels_16 = [label.replace('15', '17') for label in sg_labels_14]
sg_labels_17 = [label.replace('15', '18') for label in sg_labels_14]

# %%
# Filter the data to include only the fields we want

ind_data_14 = data2014[ind_labels_14].dropna()
ind_data_15 = data2015[ind_labels_15].dropna()
ind_data_16 = data2016[ind_labels_16].dropna()
ind_data_17 = data2017[ind_labels_17].dropna()
sg_data_14 = data2014[sg_labels_14].dropna()
sg_data_15 = data2015[sg_labels_15].dropna()
sg_data_16 = data2016[sg_labels_16].dropna()
sg_data_17 = data2017[sg_labels_17].dropna()

# %%
# Drop companies with <2000 MM
ind_data_14 = ind_data_14.where(ind_data_14[ind_labels_14[5]] > 2000).dropna()
ind_data_15 = ind_data_15.where(ind_data_15[ind_labels_15[5]] > 2000).dropna()
ind_data_16 = ind_data_16.where(ind_data_16[ind_labels_16[5]] > 2000).dropna()
ind_data_17 = ind_data_17.where(ind_data_17[ind_labels_17[5]] > 2000).dropna()
sg_data_14 = sg_data_14.where(sg_data_14[sg_labels_14[5]] > 2000).dropna()
sg_data_15 = sg_data_15.where(sg_data_15[sg_labels_15[5]] > 2000).dropna()
sg_data_16 = sg_data_16.where(sg_data_16[sg_labels_16[5]] > 2000).dropna()
sg_data_17 = sg_data_17.where(sg_data_17[sg_labels_17[5]] > 2000).dropna()

# %%
# Calculate transfers, premiums, costs, and reinsurance (if individual group) per member month
def calculate_pmm(df, df_labels, group):
    df["MM"] = df[df_labels[5]]
    df["Transfers"] = df[df_labels[2]]
    df["TotalCosts"] = abs(df[df_labels[4]])
    df["Enrollees"] = df["MM"] / 12
    df["TransfersPerEnrollee"] = df["Transfers"] / df["Enrollees"]
    df["TransfersPerSqrtEnrollee"] = df["Transfers"] / np.sqrt(df["Enrollees"])
    df["LogEnrollees"] = np.log(df["Enrollees"])
    df["LogTransfers"] = np.log(df["Transfers"]**2 + 1)
    df["TransfersPMM"] = df[df_labels[2]] / df[df_labels[5]]
    df["PremiumsPMM"] = abs(df[df_labels[3]] / df[df_labels[5]])
    df["CostsPMM"] = abs(df[df_labels[4]] / df[df_labels[5]])
    if group == "i":
        df["ReinsurancePMM"] = df[df_labels[7]] / df[df_labels[5]]
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"] + df["ReinsurancePMM"]
        #df["PremMinusCostsPlusReinsurancePMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["ReinsurancePMM"]
    elif group == "sg":
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["PremMinusCostsPMM"] = df["PremiumsPMM"] - df["CostsPMM"]
    df["PremMinusCostsPlusTransfersPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["SicknessPMM"] = df["CostsPMM"] - df["PremiumsPMM"]
    average_sickness = np.mean(df["SicknessPMM"])
    df["ExcessSicknessPMM"] = df["SicknessPMM"] - average_sickness
    return df

ind_data_14 = calculate_pmm(ind_data_14, ind_labels_14, "i")
ind_data_15 = calculate_pmm(ind_data_15, ind_labels_15, "i")
ind_data_16 = calculate_pmm(ind_data_16, ind_labels_16, "i")
ind_data_17 = calculate_pmm(ind_data_17, ind_labels_17, "sg")
sg_data_14 = calculate_pmm(sg_data_14, sg_labels_14, "sg")
sg_data_15 = calculate_pmm(sg_data_15, sg_labels_15, "sg")
sg_data_16 = calculate_pmm(sg_data_16, sg_labels_16, "sg")
sg_data_17 = calculate_pmm(sg_data_17, sg_labels_17, "sg")

# %%
# Combine the dataframes by left merging

ind_data = ind_data_14.merge(ind_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(ind_data_16, on='HIOS ID', how='outer').merge(ind_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
# Do the same thing for small group

sg_data = sg_data_14.merge(sg_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(sg_data_16, on='HIOS ID', how='outer').merge(sg_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
states = ["NY"]
dfs = [sg_data_14, sg_data_15, sg_data_16, sg_data_17]

# %%
dfs_new = normalize_empirical_data_to_avg_2017_dollars(dfs, states)
# Out:
# Cbar is 4398.953
# NY 14 Ratio is 0.973
# NY 15 Ratio is 0.896
# NY 16 Ratio is 0.862
# NY 17 Ratio is 0.782
# Empirical Transfers Sum = 1827788284.445

# %%
for df_temp in dfs_new:
    df_temp["TransfersNormalizedPerSqrtEnrollee"] = df_temp["TransfersNormalized"] / np.sqrt(df_temp["Enrollees"])

# %%
#dfs_new[3][["TransfersPerSqrtEnrollee", "TransfersNormalizedPerSqrtEnrollee"]]

# %%
df2 = create_df2(states, dfs_new, "TransfersNormalizedPerSqrtEnrollee")

# %%
k = len(df2)
v = np.linspace(0, max(abs(df2)), 10000)
v = v[1:len(v)]

ratios = [ratio_list(df2, vi) for vi in v]
#print(ratios)
begin_p = 5/k
end_p = 1-begin_p
start_index = 0
end_index = 0
for index, ratio2 in enumerate(ratios):
    if ratio2 >= begin_p:
        start_index = index
        break
    
for index, ratio2 in enumerate(ratios):
    if ratio2 > end_p:
        end_index = index
        break

if end_index == 0:
    end_index = len(v) - 1
    
v = v[start_index:end_index]

ratios2 = ratios[start_index:end_index]
multiplier = [np.sqrt(2)/vi for vi in v]
#plt.plot(v, ratios2)
#plt.plot(v, multiplier)

# %%
y = [multiplier[i] * special.erfinv(ratio2) for i, ratio2 in enumerate(ratios2)]
#plt.plot(v, y)
#plt.title("1/beta vs. v")
beta = [1/yi for yi in y]
#plt.plot(v, beta)
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
#plt.title("beta vs. v")

# %%
# Finding the minimum beta
# Whenever we reject a beta, we reject all betas greater than that,
# so keep pushing beta smaller until we reach max_difference == test_statistic
# Run test for larger data sizes (combining states, years)

# %%
max_beta=max(beta)
max_beta = int(max_beta/100)*100

# %%
theoretical = [special.erf(vi/(max_beta*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v)")
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (states, len(df2)))
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
plt.legend()
print("beta = %.3f" % (max_beta))
# Out:
# beta = 174400.000

# %%
beta_theoretical, Mb_index = run_test_against_theoretical(df2, max_beta, ratios2, False)
# Out:
# k = 79
# test_stat at this k = 0.13551
#
# At the point of maximum difference with beta = 174400:
# P(|d_i|<v) = 0.7722
# P(|N(0,max_beta^2)|<v) = 0.3616
# Difference = 0.4105
#
#
#
#
# At the point of maximum difference with beta = 164400:
# P(|d_i|<v) = 0.7722
# P(|N(0,max_beta^2)|<v) = 0.3819
# Difference = 0.3902
#
#
#
#
# At the point of maximum difference with beta = 154400:
# P(|d_i|<v) = 0.7722
# P(|N(0,max_beta^2)|<v) = 0.4045
# Difference = 0.3677
#
#
#
#
# At the point of maximum difference with beta = 144400:
# P(|d_i|<v) = 0.7722
# P(|N(0,max_beta^2)|<v) = 0.4297
# Difference = 0.3424
#
#
#
#
# At the point of maximum difference with beta = 134400:
# P(|d_i|<v) = 0.7722
# P(|N(0,max_beta^2)|<v) = 0.4581
# Difference = 0.3141
#
#
#
#
# At the point of maximum difference with beta = 124400:
# P(|d_i|<v) = 0.7722
# P(|N(0,max_beta^2)|<v) = 0.4900
# Difference = 0.2821
#
#
#
#
# At the point of maximum difference with beta = 114400:
# P(|d_i|<v) = 0.6456
# P(|N(0,max_beta^2)|<v) = 0.3943
# Difference = 0.2512
#
#
#
#
# At the point of maximum difference with beta = 104400:
# P(|d_i|<v) = 0.6456
# P(|N(0,max_beta^2)|<v) = 0.4284
# Difference = 0.2172
#
#
#
#
# At the point of maximum difference with beta = 94400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3329
# Difference = 0.1861
#
#
#
#
# At the point of maximum difference with beta = 84400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3696
# Difference = 0.1494
#
#
#
#
# At the point of maximum difference with beta = 84400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3696
# Difference = 0.1494
#
#
#
#
# At the point of maximum difference with beta = 84300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3700
# Difference = 0.1490
#
#
#
#
# At the point of maximum difference with beta = 84200:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3704
# Difference = 0.1486
#
#
#
#
# At the point of maximum difference with beta = 84100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3708
# Difference = 0.1482
#
#
#
#
# At the point of maximum difference with beta = 84000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3712
# Difference = 0.1478
#
#
#
#
# At the point of maximum difference with beta = 83900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3716
# Difference = 0.1474
#
#
#
#
# At the point of maximum difference with beta = 83800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3720
# Difference = 0.1470
#
#
#
#
# At the point of maximum difference with beta = 83700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3724
# Difference = 0.1466
#
#
#
#
# At the point of maximum difference with beta = 83600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3728
# Difference = 0.1461
#
#
#
#
# At the point of maximum difference with beta = 83500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3733
# Difference = 0.1457
#
#
#
#
# At the point of maximum difference with beta = 83400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3737
# Difference = 0.1453
#
#
#
#
# At the point of maximum difference with beta = 83300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3741
# Difference = 0.1449
#
#
#
#
# At the point of maximum difference with beta = 83200:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3745
# Difference = 0.1445
#
#
#
#
# At the point of maximum difference with beta = 83100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3749
# Difference = 0.1441
#
#
#
#
# At the point of maximum difference with beta = 83000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3753
# Difference = 0.1437
#
#
#
#
# At the point of maximum difference with beta = 82900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3757
# Difference = 0.1432
#
#
#
#
# At the point of maximum difference with beta = 82800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3762
# Difference = 0.1428
#
#
#
#
# At the point of maximum difference with beta = 82700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3766
# Difference = 0.1424
#
#
#
#
# At the point of maximum difference with beta = 82600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3770
# Difference = 0.1420
#
#
#
#
# At the point of maximum difference with beta = 82500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3774
# Difference = 0.1416
#
#
#
#
# At the point of maximum difference with beta = 82400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3779
# Difference = 0.1411
#
#
#
#
# At the point of maximum difference with beta = 82300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3783
# Difference = 0.1407
#
#
#
#
# At the point of maximum difference with beta = 82200:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3787
# Difference = 0.1403
#
#
#
#
# At the point of maximum difference with beta = 82100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3791
# Difference = 0.1399
#
#
#
#
# At the point of maximum difference with beta = 82000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3795
# Difference = 0.1394
#
#
#
#
# At the point of maximum difference with beta = 81900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3800
# Difference = 0.1390
#
#
#
#
# At the point of maximum difference with beta = 81800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3804
# Difference = 0.1386
#
#
#
#
# At the point of maximum difference with beta = 81700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3808
# Difference = 0.1382
#
#
#
#
# At the point of maximum difference with beta = 81600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3813
# Difference = 0.1377
#
#
#
#
# At the point of maximum difference with beta = 81500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3817
# Difference = 0.1373
#
#
#
#
# At the point of maximum difference with beta = 81400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3821
# Difference = 0.1369
#
#
#
#
# At the point of maximum difference with beta = 81300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3826
# Difference = 0.1364
#
#
#
#
# At the point of maximum difference with beta = 81200:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3830
# Difference = 0.1360
#
#
#
#
# At the point of maximum difference with beta = 81100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3834
# Difference = 0.1356

# %%
beta_theoretical = beta_theoretical+100

theoretical = [special.erf(vi/(beta_theoretical*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) beta=%d" % (beta_theoretical))
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (states, len(df2)))
plt.axvline(x=v[Mb_index], color='r', linestyle='--', label="Point of max difference")
plt.legend()
#plt.xlim(0, 50000)
#print("beta = %.3f" % (max_beta))

# %%
print("Theoretical Test Results")
run_binom_stat_test2(beta_theoretical, df2.values)
# Out:
# Theoretical Test Results
# Beta (=std): 81100
# Number of T/sqrt(n) above 2 stds: 14
# Proportion of T/sqrt(n) above 2 stds: 0.177
# P value = 0.000002

# %%
ratios_c, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta_theoretical - 10000)
ratios_c2, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta_theoretical)
ratios_c3, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta_theoretical + 10000)
# Out:
# Sum sqrt(a) = 12836.434
# Sum sqrt(a) = 12836.434
# Sum sqrt(a) = 12836.434

# %%
theoretical = [special.erf(vi/(beta_theoretical*np.sqrt(2))) for vi in v]

plt.figure(figsize=(10, 7))
plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) with beta = %d" % (beta_theoretical))
plt.plot(v, ratios2, label="P(|d_i|<v) = empirical distribution")
plt.plot(v, ratios_c, label="Simulation with es = %d, 5 times" % (beta_theoretical - 10000))
plt.plot(v, ratios_c2, label="Simulation with es = %d, 5 times" % (beta_theoretical))
plt.plot(v, ratios_c3, label="Simulation with es = %d, 5 times" % (beta_theoretical + 10000))
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s (k=%d)" % (states, len(df2)))
plt.legend()

# %%
beta_sims = list()

for i in range(5):
    beta_sim, _= run_test_against_simulation(states, dfs_new, beta_theoretical, ratios2, False)
    beta_sims.append(beta_sim)
# Out:
# k = 79
# test_stat at this k = 0.13551
#
# At the point of maximum difference with beta = 105100:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2726
# Difference = 0.1831
#
#
#
#
# At the point of maximum difference with beta = 105000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3376
# Difference = 0.1814
#
#
#
#
# At the point of maximum difference with beta = 104900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3570
# Difference = 0.1620
#
#
#
#
# At the point of maximum difference with beta = 104800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3485
# Difference = 0.1705
#
#
#
#
# At the point of maximum difference with beta = 104700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3494
# Difference = 0.1696
#
#
#
#
# At the point of maximum difference with beta = 104600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3586
# Difference = 0.1603
#
#
#
#
# At the point of maximum difference with beta = 104500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3536
# Difference = 0.1654
#
#
#
#
# At the point of maximum difference with beta = 104400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3570
# Difference = 0.1620
#
#
#
#
# At the point of maximum difference with beta = 104300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3705
# Difference = 0.1485
#
#
#
#
# At the point of maximum difference with beta = 104200:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2928
# Difference = 0.1629
#
#
#
#
# At the point of maximum difference with beta = 104100:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3612
# Difference = 0.1451
#
#
#
#
# At the point of maximum difference with beta = 104000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3671
# Difference = 0.1519
#
#
#
#
# At the point of maximum difference with beta = 103900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3679
# Difference = 0.1511
#
#
#
#
# At the point of maximum difference with beta = 103800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3511
# Difference = 0.1679
#
#
#
#
# At the point of maximum difference with beta = 103700:
# P(|d_i|<v) = 0.6456
# P(|N(0,max_beta^2)|<v) = 0.4743
# Difference = 0.1713
#
#
#
#
# At the point of maximum difference with beta = 103600:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2911
# Difference = 0.1646
#
#
#
#
# At the point of maximum difference with beta = 103500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3603
# Difference = 0.1586
#
#
#
#
# At the point of maximum difference with beta = 103400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3578
# Difference = 0.1612
#
#
#
#
# At the point of maximum difference with beta = 103300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3553
# Difference = 0.1637
#
#
#
#
# At the point of maximum difference with beta = 103200:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3814
# Difference = 0.1376
#
#
#
#
# At the point of maximum difference with beta = 103100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3451
# Difference = 0.1738
#
#
#
#
# At the point of maximum difference with beta = 103000:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2928
# Difference = 0.1629
#
#
#
#
# At the point of maximum difference with beta = 102900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3561
# Difference = 0.1629
#
#
#
#
# At the point of maximum difference with beta = 102800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3595
# Difference = 0.1595
#
#
#
#
# At the point of maximum difference with beta = 102700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3553
# Difference = 0.1637
#
#
#
#
# At the point of maximum difference with beta = 102600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3662
# Difference = 0.1527
#
#
#
#
# At the point of maximum difference with beta = 102500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3561
# Difference = 0.1629
#
#
#
#
# At the point of maximum difference with beta = 102400:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.3097
# Difference = 0.1460
#
#
#
#
# At the point of maximum difference with beta = 102300:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2954
# Difference = 0.1603
#
#
#
#
# At the point of maximum difference with beta = 102200:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2819
# Difference = 0.1738
#
#
#
#
# At the point of maximum difference with beta = 102100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3511
# Difference = 0.1679
#
#
#
#
# At the point of maximum difference with beta = 102000:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3392
# Difference = 0.1671
#
#
#
#
# At the point of maximum difference with beta = 101900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3570
# Difference = 0.1620
#
#
#
#
# At the point of maximum difference with beta = 101800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3637
# Difference = 0.1553
#
#
#
#
# At the point of maximum difference with beta = 101700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3620
# Difference = 0.1570
#
#
#
#
# At the point of maximum difference with beta = 101600:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.3063
# Difference = 0.1494
#
#
#
#
# At the point of maximum difference with beta = 101500:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.3013
# Difference = 0.1544
#
#
#
#
# At the point of maximum difference with beta = 101400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3671
# Difference = 0.1519
#
#
#
#
# At the point of maximum difference with beta = 101300:
# P(|d_i|<v) = 0.4810
# P(|N(0,max_beta^2)|<v) = 0.3131
# Difference = 0.1679
#
#
#
#
# At the point of maximum difference with beta = 101200:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3595
# Difference = 0.1595
#
#
#
#
# At the point of maximum difference with beta = 101100:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2920
# Difference = 0.1637
#
#
#
#
# At the point of maximum difference with beta = 101000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3418
# Difference = 0.1772
#
#
#
#
# At the point of maximum difference with beta = 100900:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2886
# Difference = 0.1671
#
#
#
#
# At the point of maximum difference with beta = 100800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3426
# Difference = 0.1764
#
#
#
#
# At the point of maximum difference with beta = 100700:
# P(|d_i|<v) = 0.4810
# P(|N(0,max_beta^2)|<v) = 0.3367
# Difference = 0.1443
#
#
#
#
# At the point of maximum difference with beta = 100600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3468
# Difference = 0.1722
#
#
#
#
# At the point of maximum difference with beta = 100500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3578
# Difference = 0.1612
#
#
#
#
# At the point of maximum difference with beta = 100400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3477
# Difference = 0.1713
#
#
#
#
# At the point of maximum difference with beta = 100300:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3612
# Difference = 0.1451
#
#
#
#
# At the point of maximum difference with beta = 100200:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.3004
# Difference = 0.1553
#
#
#
#
# At the point of maximum difference with beta = 100100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3671
# Difference = 0.1519
#
#
#
#
# At the point of maximum difference with beta = 100000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3696
# Difference = 0.1494
#
#
#
#
# At the point of maximum difference with beta = 99900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3823
# Difference = 0.1367
#
#
#
#
# At the point of maximum difference with beta = 99800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3713
# Difference = 0.1477
#
#
#
#
# At the point of maximum difference with beta = 99700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3696
# Difference = 0.1494
#
#
#
#
# At the point of maximum difference with beta = 99600:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3620
# Difference = 0.1443
#
#
#
#
# At the point of maximum difference with beta = 99500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3831
# Difference = 0.1359
#
#
#
#
# At the point of maximum difference with beta = 99400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3359
# Difference = 0.1831
#
#
#
#
# At the point of maximum difference with beta = 99300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3646
# Difference = 0.1544
#
#
#
#
# At the point of maximum difference with beta = 99200:
# P(|d_i|<v) = 0.6456
# P(|N(0,max_beta^2)|<v) = 0.5030
# Difference = 0.1426
#
#
#
#
# At the point of maximum difference with beta = 99100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3772
# Difference = 0.1418
#
#
#
#
# At the point of maximum difference with beta = 99000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3620
# Difference = 0.1570
#
#
#
#
# At the point of maximum difference with beta = 98900:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.3055
# Difference = 0.1502
# At the point of maximum difference with beta = 98800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3553
# Difference = 0.1637
#
#
#
#
# At the point of maximum difference with beta = 98700:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2987
# Difference = 0.1570
#
#
#
#
# At the point of maximum difference with beta = 98600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3637
# Difference = 0.1553
#
#
#
#
# At the point of maximum difference with beta = 98500:
# P(|d_i|<v) = 0.2278
# P(|N(0,max_beta^2)|<v) = 0.0954
# Difference = 0.1325 NOT > test_stat
# k = 79
# test_stat at this k = 0.13551
#
# At the point of maximum difference with beta = 105100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3696
# Difference = 0.1494
#
#
#
#
# At the point of maximum difference with beta = 105000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3426
# Difference = 0.1764
#
#
#
#
# At the point of maximum difference with beta = 104900:
# P(|d_i|<v) = 0.6456
# P(|N(0,max_beta^2)|<v) = 0.4692
# Difference = 0.1764
#
#
#
#
# At the point of maximum difference with beta = 104800:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3257
# Difference = 0.1806
#
#
#
#
# At the point of maximum difference with beta = 104700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3586
# Difference = 0.1603
#
#
#
#
# At the point of maximum difference with beta = 104600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3705
# Difference = 0.1485
#
#
#
#
# At the point of maximum difference with beta = 104500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3376
# Difference = 0.1814
#
#
#
#
# At the point of maximum difference with beta = 104400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3705
# Difference = 0.1485
#
#
#
#
# At the point of maximum difference with beta = 104300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3477
# Difference = 0.1713
#
#
#
#
# At the point of maximum difference with beta = 104200:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3705
# Difference = 0.1485
#
#
#
#
# At the point of maximum difference with beta = 104100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3367
# Difference = 0.1823
#
#
#
#
# At the point of maximum difference with beta = 104000:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3376
# Difference = 0.1688
#
#
#
#
# At the point of maximum difference with beta = 103900:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3502
# Difference = 0.1561
#
#
#
#
# At the point of maximum difference with beta = 103800:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2928
# Difference = 0.1629
#
#
#
#
# At the point of maximum difference with beta = 103700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3241
# Difference = 0.1949
#
#
#
#
# At the point of maximum difference with beta = 103600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3586
# Difference = 0.1603
#
#
#
#
# At the point of maximum difference with beta = 103500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3392
# Difference = 0.1797
#
#
#
#
# At the point of maximum difference with beta = 103400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3527
# Difference = 0.1662
#
#
#
#
# At the point of maximum difference with beta = 103300:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2861
# Difference = 0.1696
#
#
#
#
# At the point of maximum difference with beta = 103200:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2903
# Difference = 0.1654
#
#
#
#
# At the point of maximum difference with beta = 103100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3637
# Difference = 0.1553
#
#
#
#
# At the point of maximum difference with beta = 103000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3485
# Difference = 0.1705
#
#
#
#
# At the point of maximum difference with beta = 102900:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.3181
# Difference = 0.1376
#
#
#
#
# At the point of maximum difference with beta = 102800:
# P(|d_i|<v) = 0.4304
# P(|N(0,max_beta^2)|<v) = 0.2734
# Difference = 0.1570
#
#
#
#
# At the point of maximum difference with beta = 102700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3359
# Difference = 0.1831
#
#
#
#
# At the point of maximum difference with beta = 102600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3409
# Difference = 0.1781
#
#
#
#
# At the point of maximum difference with beta = 102500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3418
# Difference = 0.1772
#
#
#
#
# At the point of maximum difference with beta = 102400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3688
# Difference = 0.1502
#
#
#
#
# At the point of maximum difference with beta = 102300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3705
# Difference = 0.1485
#
#
#
#
# At the point of maximum difference with beta = 102200:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3325
# Difference = 0.1865
#
#
#
#
# At the point of maximum difference with beta = 102100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3578
# Difference = 0.1612
#
#
#
#
# At the point of maximum difference with beta = 102000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3519
# Difference = 0.1671
#
#
#
#
# At the point of maximum difference with beta = 101900:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2954
# Difference = 0.1603
#
#
#
#
# At the point of maximum difference with beta = 101800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3553
# Difference = 0.1637
#
#
#
#
# At the point of maximum difference with beta = 101700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3772
# Difference = 0.1418
#
#
#
#
# At the point of maximum difference with beta = 101600:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3586
# Difference = 0.1477
#
#
#
#
# At the point of maximum difference with beta = 101500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3814
# Difference = 0.1376
#
#
#
#
# At the point of maximum difference with beta = 101400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3451
# Difference = 0.1738
#
#
#
#
# At the point of maximum difference with beta = 101300:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2954
# Difference = 0.1603
#
#
#
#
# At the point of maximum difference with beta = 101200:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3561
# Difference = 0.1629
#
#
#
#
# At the point of maximum difference with beta = 101100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3789
# Difference = 0.1401
#
#
#
#
# At the point of maximum difference with beta = 101000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3713
# Difference = 0.1477
#
#
#
#
# At the point of maximum difference with beta = 100900:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3257
# Difference = 0.1806
#
#
#
#
# At the point of maximum difference with beta = 100800:
# P(|d_i|<v) = 0.4810
# P(|N(0,max_beta^2)|<v) = 0.3173
# Difference = 0.1637
#
#
#
#
# At the point of maximum difference with beta = 100700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3696
# Difference = 0.1494
#
#
#
#
# At the point of maximum difference with beta = 100600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3637
# Difference = 0.1553
#
#
#
#
# At the point of maximum difference with beta = 100500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3882
# Difference = 0.1308 NOT > test_stat
# k = 79
# test_stat at this k = 0.13551
#
# At the point of maximum difference with beta = 105100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3654
# Difference = 0.1536
#
#
#
#
# At the point of maximum difference with beta = 105000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3629
# Difference = 0.1561
#
#
#
#
# At the point of maximum difference with beta = 104900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3426
# Difference = 0.1764
#
#
#
#
# At the point of maximum difference with beta = 104800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3722
# Difference = 0.1468
#
#
#
#
# At the point of maximum difference with beta = 104700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3333
# Difference = 0.1857
#
#
#
#
# At the point of maximum difference with beta = 104600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3359
# Difference = 0.1831
#
#
#
#
# At the point of maximum difference with beta = 104500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3460
# Difference = 0.1730
#
#
#
#
# At the point of maximum difference with beta = 104400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3595
# Difference = 0.1595
#
#
#
#
# At the point of maximum difference with beta = 104300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3435
# Difference = 0.1755
#
#
#
#
# At the point of maximum difference with beta = 104200:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3257
# Difference = 0.1932
#
#
#
#
# At the point of maximum difference with beta = 104100:
# P(|d_i|<v) = 0.4304
# P(|N(0,max_beta^2)|<v) = 0.2582
# Difference = 0.1722
# At the point of maximum difference with beta = 104000:
# P(|d_i|<v) = 0.6456
# P(|N(0,max_beta^2)|<v) = 0.4717
# Difference = 0.1738
#
#
#
#
# At the point of maximum difference with beta = 103900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3494
# Difference = 0.1696
#
#
#
#
# At the point of maximum difference with beta = 103800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3443
# Difference = 0.1747
#
#
#
#
# At the point of maximum difference with beta = 103700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3696
# Difference = 0.1494
#
#
#
#
# At the point of maximum difference with beta = 103600:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3468
# Difference = 0.1595
#
#
#
#
# At the point of maximum difference with beta = 103500:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2835
# Difference = 0.1722
#
#
#
#
# At the point of maximum difference with beta = 103400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3637
# Difference = 0.1553
#
#
#
#
# At the point of maximum difference with beta = 103300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3494
# Difference = 0.1696
#
#
#
#
# At the point of maximum difference with beta = 103200:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3612
# Difference = 0.1578
#
#
#
#
# At the point of maximum difference with beta = 103100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3401
# Difference = 0.1789
#
#
#
#
# At the point of maximum difference with beta = 103000:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3477
# Difference = 0.1586
#
#
#
#
# At the point of maximum difference with beta = 102900:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2675
# Difference = 0.1882
#
#
#
#
# At the point of maximum difference with beta = 102800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3494
# Difference = 0.1696
#
#
#
#
# At the point of maximum difference with beta = 102700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3468
# Difference = 0.1722
#
#
#
#
# At the point of maximum difference with beta = 102600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3224
# Difference = 0.1966
#
#
#
#
# At the point of maximum difference with beta = 102500:
# P(|d_i|<v) = 0.6835
# P(|N(0,max_beta^2)|<v) = 0.5224
# Difference = 0.1612
#
#
#
#
# At the point of maximum difference with beta = 102400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3578
# Difference = 0.1612
#
#
#
#
# At the point of maximum difference with beta = 102300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3468
# Difference = 0.1722
#
#
#
#
# At the point of maximum difference with beta = 102200:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3401
# Difference = 0.1662
#
#
#
#
# At the point of maximum difference with beta = 102100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3620
# Difference = 0.1570
#
#
#
#
# At the point of maximum difference with beta = 102000:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2996
# Difference = 0.1561
#
#
#
#
# At the point of maximum difference with beta = 101900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3662
# Difference = 0.1527
#
#
#
#
# At the point of maximum difference with beta = 101800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3857
# Difference = 0.1333 NOT > test_stat
# k = 79
# test_stat at this k = 0.13551
#
# At the point of maximum difference with beta = 105100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3553
# Difference = 0.1637
#
#
#
#
# At the point of maximum difference with beta = 105000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3705
# Difference = 0.1485
#
#
#
#
# At the point of maximum difference with beta = 104900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3637
# Difference = 0.1553
#
#
#
#
# At the point of maximum difference with beta = 104800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3662
# Difference = 0.1527
#
#
#
#
# At the point of maximum difference with beta = 104700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3418
# Difference = 0.1772
#
#
#
#
# At the point of maximum difference with beta = 104600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3485
# Difference = 0.1705
#
#
#
#
# At the point of maximum difference with beta = 104500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3536
# Difference = 0.1654
#
#
#
#
# At the point of maximum difference with beta = 104400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3553
# Difference = 0.1637
#
#
#
#
# At the point of maximum difference with beta = 104300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3696
# Difference = 0.1494
#
#
#
#
# At the point of maximum difference with beta = 104200:
# P(|d_i|<v) = 0.6456
# P(|N(0,max_beta^2)|<v) = 0.4970
# Difference = 0.1485
#
#
#
#
# At the point of maximum difference with beta = 104100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3426
# Difference = 0.1764
#
#
#
#
# At the point of maximum difference with beta = 104000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3173
# Difference = 0.2017
#
#
#
#
# At the point of maximum difference with beta = 103900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3570
# Difference = 0.1620
#
#
#
#
# At the point of maximum difference with beta = 103800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3688
# Difference = 0.1502
#
#
#
#
# At the point of maximum difference with beta = 103700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3451
# Difference = 0.1738
#
#
#
#
# At the point of maximum difference with beta = 103600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3722
# Difference = 0.1468
#
#
#
#
# At the point of maximum difference with beta = 103500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3477
# Difference = 0.1713
#
#
#
#
# At the point of maximum difference with beta = 103400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3722
# Difference = 0.1468
#
#
#
#
# At the point of maximum difference with beta = 103300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3671
# Difference = 0.1519
#
#
#
#
# At the point of maximum difference with beta = 103200:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.3004
# Difference = 0.1553
#
#
#
#
# At the point of maximum difference with beta = 103100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3637
# Difference = 0.1553
#
#
#
#
# At the point of maximum difference with beta = 103000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3586
# Difference = 0.1603
#
#
#
#
# At the point of maximum difference with beta = 102900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3603
# Difference = 0.1586
#
#
#
#
# At the point of maximum difference with beta = 102800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3561
# Difference = 0.1629
#
#
#
#
# At the point of maximum difference with beta = 102700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3612
# Difference = 0.1578
#
#
#
#
# At the point of maximum difference with beta = 102600:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2886
# Difference = 0.1671
#
#
#
#
# At the point of maximum difference with beta = 102500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3603
# Difference = 0.1586
#
#
#
#
# At the point of maximum difference with beta = 102400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3544
# Difference = 0.1646
#
#
#
#
# At the point of maximum difference with beta = 102300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3840
# Difference = 0.1350 NOT > test_stat
# k = 79
# test_stat at this k = 0.13551
#
# At the point of maximum difference with beta = 105100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3494
# Difference = 0.1696
#
#
#
#
# At the point of maximum difference with beta = 105000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3603
# Difference = 0.1586
#
#
#
#
# At the point of maximum difference with beta = 104900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3544
# Difference = 0.1646
#
#
#
#
# At the point of maximum difference with beta = 104800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3392
# Difference = 0.1797
#
#
#
#
# At the point of maximum difference with beta = 104700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3460
# Difference = 0.1730
#
#
#
#
# At the point of maximum difference with beta = 104600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3342
# Difference = 0.1848
#
#
#
#
# At the point of maximum difference with beta = 104500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3325
# Difference = 0.1865
#
#
#
#
# At the point of maximum difference with beta = 104400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3637
# Difference = 0.1553
#
#
#
#
# At the point of maximum difference with beta = 104300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3916
# Difference = 0.1274 NOT > test_stat

# %%
print("Simulation without Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sims), df2.values)
run_binom_stat_test3(np.mean(beta_sims), df2.values)
# Out:
# Simulation without Adjustment Test Results
# Beta (=std): 101480
# Number of T/sqrt(n) above 2 stds: 12
# Proportion of T/sqrt(n) above 2 stds: 0.152
# P value = 0.000056
# Beta (=std): 101480
# Number of T/sqrt(n) above 3 stds: 5
# Proportion of T/sqrt(n) above 3 stds: 0.063
# P value = 0.000000

# %%
beta_sim_adjs = list()

for i in range(5):
    beta_sim_adj, _= run_test_against_simulation_adjust_for_imbalances(states, dfs_new,
                                                                   beta_theoretical, ratios2, False)
    beta_sim_adjs.append(beta_sim_adj)
# Out:
# k = 79
# test_stat at this k = 0.13551
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 105100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3536
# Difference = 0.1654
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 105000:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2937
# Difference = 0.1620
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3401
# Difference = 0.1789
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104800:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2827
# Difference = 0.1730
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3477
# Difference = 0.1713
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104600:
# P(|d_i|<v) = 0.4810
# P(|N(0,max_beta^2)|<v) = 0.3173
# Difference = 0.1637
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3544
# Difference = 0.1646
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3485
# Difference = 0.1705
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3612
# Difference = 0.1578
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104200:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3722
# Difference = 0.1468
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3629
# Difference = 0.1561
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3806
# Difference = 0.1384
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3612
# Difference = 0.1578
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103800:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3553
# Difference = 0.1511
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3797
# Difference = 0.1392
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3679
# Difference = 0.1511
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3806
# Difference = 0.1384
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103400:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3586
# Difference = 0.1477
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3595
# Difference = 0.1595
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103200:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2970
# Difference = 0.1586
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103100:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3629
# Difference = 0.1435
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103000:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.3165
# Difference = 0.1392
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 102900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3578
# Difference = 0.1612
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 102800:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2996
# Difference = 0.1561
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 102700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3713
# Difference = 0.1477
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 102600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3527
# Difference = 0.1662
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 102500:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3485
# Difference = 0.1578
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 102400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3907
# Difference = 0.1283 NOT > test_stat
# E(|X|) = 1048779995.311
# k = 79
# test_stat at this k = 0.13551
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 105100:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3451
# Difference = 0.1612
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 105000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3603
# Difference = 0.1586
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3443
# Difference = 0.1747
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3460
# Difference = 0.1730
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3570
# Difference = 0.1620
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3637
# Difference = 0.1553
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3688
# Difference = 0.1502
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104400:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3527
# Difference = 0.1536
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3603
# Difference = 0.1586
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104200:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3671
# Difference = 0.1519
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3527
# Difference = 0.1662
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3376
# Difference = 0.1814
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103900:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2819
# Difference = 0.1738
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103800:
# P(|d_i|<v) = 0.4810
# P(|N(0,max_beta^2)|<v) = 0.3333
# Difference = 0.1477
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103700:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3367
# Difference = 0.1696
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103600:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.3021
# Difference = 0.1536
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103500:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.3063
# Difference = 0.1494
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103400:
# P(|d_i|<v) = 0.6456
# P(|N(0,max_beta^2)|<v) = 0.5215
# Difference = 0.1241 NOT > test_stat
# E(|X|) = 1059021987.453
# k = 79
# test_stat at this k = 0.13551
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 105100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3553
# Difference = 0.1637
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 105000:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.3038
# Difference = 0.1519
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104900:
# P(|d_i|<v) = 0.6456
# P(|N(0,max_beta^2)|<v) = 0.4835
# Difference = 0.1620
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3561
# Difference = 0.1629
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3544
# Difference = 0.1646
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3722
# Difference = 0.1468
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3300
# Difference = 0.1890
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104400:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3570
# Difference = 0.1620
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104300:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3511
# Difference = 0.1553
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104200:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3435
# Difference = 0.1755
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3544
# Difference = 0.1646
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104000:
# P(|d_i|<v) = 0.6456
# P(|N(0,max_beta^2)|<v) = 0.4895
# Difference = 0.1561
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103900:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.3139
# Difference = 0.1418
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3536
# Difference = 0.1654
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103700:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.3173
# Difference = 0.1384
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3409
# Difference = 0.1781
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103500:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.3055
# Difference = 0.1502
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103400:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2987
# Difference = 0.1570
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103300:
# P(|d_i|<v) = 0.4810
# P(|N(0,max_beta^2)|<v) = 0.2996
# Difference = 0.1814
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103200:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3511
# Difference = 0.1679
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3671
# Difference = 0.1519
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103000:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3325
# Difference = 0.1738
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 102900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3544
# Difference = 0.1646
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 102800:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.2844
# Difference = 0.1713
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 102700:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3730
# Difference = 0.1333 NOT > test_stat
# E(|X|) = 1051852592.954
# k = 79
# test_stat at this k = 0.13551
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 105100:
# P(|d_i|<v) = 0.4810
# P(|N(0,max_beta^2)|<v) = 0.3156
# Difference = 0.1654
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 105000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3595
# Difference = 0.1595
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3502
# Difference = 0.1688
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3823
# Difference = 0.1367
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104700:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3823
# Difference = 0.1367
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104600:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3671
# Difference = 0.1519
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104500:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3359
# Difference = 0.1831
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104400:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3241
# Difference = 0.1823
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104300:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3511
# Difference = 0.1679
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104200:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3519
# Difference = 0.1544
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104100:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3722
# Difference = 0.1468
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 104000:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3595
# Difference = 0.1595
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103900:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3536
# Difference = 0.1654
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103800:
# P(|d_i|<v) = 0.5190
# P(|N(0,max_beta^2)|<v) = 0.3612
# Difference = 0.1578
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 103700:
# P(|d_i|<v) = 0.5063
# P(|N(0,max_beta^2)|<v) = 0.3713
# Difference = 0.1350 NOT > test_stat
# E(|X|) = 1062094585.096
# k = 79
# test_stat at this k = 0.13551
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 105100:
# P(|d_i|<v) = 0.4557
# P(|N(0,max_beta^2)|<v) = 0.3089
# Difference = 0.1468
#
#
#
# Sum sqrt(a) = 12836.434
#
# At the point of maximum difference with beta = 105000:
# P(|d_i|<v) = 0.4810
# P(|N(0,max_beta^2)|<v) = 0.3468
# Difference = 0.1342 NOT > test_stat
# E(|X|) = 1075409174.880

# %%
print("Simulation WITH Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sim_adjs), df2.values)
run_binom_stat_test3(np.mean(beta_sim_adjs), df2.values)
# Out:
# Simulation WITH Adjustment Test Results
# Beta (=std): 103440
# Number of T/sqrt(n) above 2 stds: 11
# Proportion of T/sqrt(n) above 2 stds: 0.139
# P value = 0.000234
# Beta (=std): 103440
# Number of T/sqrt(n) above 3 stds: 5
# Proportion of T/sqrt(n) above 3 stds: 0.063
# P value = 0.000000

# %%
print("Theoretical Test Results")
run_binom_stat_test2(beta_theoretical, df2.values)
run_binom_stat_test3(beta_theoretical, df2.values)
print("\n")
print("Simulation without Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sims), df2.values)
run_binom_stat_test3(np.mean(beta_sims), df2.values)
print("\n")
print("Simulation WITH Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sim_adjs), df2.values)
run_binom_stat_test3(np.mean(beta_sim_adjs), df2.values)
# Out:
# Theoretical Test Results
# Beta (=std): 81100
# Number of T/sqrt(n) above 2 stds: 14
# Proportion of T/sqrt(n) above 2 stds: 0.177
# P value = 0.000002
# Beta (=std): 81100
# Number of T/sqrt(n) above 3 stds: 8
# Proportion of T/sqrt(n) above 3 stds: 0.101
# P value = 0.000000
#
#
# Simulation without Adjustment Test Results
# Beta (=std): 101480
# Number of T/sqrt(n) above 2 stds: 12
# Proportion of T/sqrt(n) above 2 stds: 0.152
# P value = 0.000056
# Beta (=std): 101480
# Number of T/sqrt(n) above 3 stds: 5
# Proportion of T/sqrt(n) above 3 stds: 0.063
# P value = 0.000000
#
#
# Simulation WITH Adjustment Test Results
# Beta (=std): 103440
# Number of T/sqrt(n) above 2 stds: 11
# Proportion of T/sqrt(n) above 2 stds: 0.139
# P value = 0.000234
# Beta (=std): 103440
# Number of T/sqrt(n) above 3 stds: 5
# Proportion of T/sqrt(n) above 3 stds: 0.063
# P value = 0.000000

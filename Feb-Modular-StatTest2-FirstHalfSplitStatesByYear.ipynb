# %%
# %run StatTest2_WithSimulation_Setup.ipynb
# Out:
# {0: ['ME', 'IL', 'PA', 'GA', 'OK', 'DE', 'WA', 'CT', 'OH', 'VA', 'NE', 'MT', 'IN', 'CA', 'HI', 'ND', 'MD', 'SC', 'RI', 'AK', 'KY', 'WI', 'LA', 'MN', 'MS', 'WV', 'FL'], 1: ['SD', 'IL', 'PA', 'NH', 'NM', 'NV', 'OK', 'UT', 'CT', 'OH', 'VA', 'OR', 'CO', 'IN', 'HI', 'AL', 'RI', 'AK', 'LA', 'MN', 'IA', 'AR', 'WV'], 2: ['MI', 'ME', 'WY', 'DC', 'TX', 'AZ', 'NC', 'WA', 'OR', 'CO', 'MT', 'ND', 'TN', 'SC', 'AL', 'NY', 'KY', 'NJ', 'KS', 'ID', 'IA', 'AR', 'MO'], 3: ['MI', 'SD', 'WY', 'NH', 'DC', 'TX', 'GA', 'AZ', 'NM', 'NC', 'NV', 'DE', 'UT', 'NE', 'CA', 'MD', 'TN', 'NY', 'NJ', 'KS', 'WI', 'ID', 'MS', 'FL', 'MO']}
# {0: ['MI', 'SD', 'WY', 'NH', 'DC', 'TX', 'AZ', 'NM', 'NC', 'NV', 'UT', 'OR', 'CO', 'TN', 'AL', 'NY', 'NJ', 'KS', 'ID', 'IA', 'AR', 'MO'], 1: ['MI', 'ME', 'WY', 'DC', 'TX', 'GA', 'AZ', 'NC', 'DE', 'WA', 'NE', 'MT', 'CA', 'ND', 'MD', 'TN', 'SC', 'NY', 'KY', 'NJ', 'KS', 'WI', 'ID', 'MS', 'FL', 'MO'], 2: ['SD', 'IL', 'PA', 'NH', 'GA', 'NM', 'NV', 'OK', 'DE', 'UT', 'CT', 'OH', 'VA', 'NE', 'IN', 'CA', 'HI', 'MD', 'RI', 'AK', 'WI', 'LA', 'MN', 'MS', 'WV', 'FL'], 3: ['ME', 'IL', 'PA', 'OK', 'WA', 'CT', 'OH', 'VA', 'OR', 'CO', 'MT', 'IN', 'HI', 'ND', 'SC', 'AL', 'RI', 'AK', 'KY', 'LA', 'MN', 'IA', 'AR', 'WV']}

# %%
data2014 = pd.read_csv("Our_Dataset/2014dataset.csv")
data2015 = pd.read_csv("Our_Dataset/2015dataset.csv")
data2016 = pd.read_csv("Our_Dataset/2016dataset.csv")
data2017 = pd.read_csv("Our_Dataset/2017dataset.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,52,323,649,882,932,1092,1202) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,57,204,341,376,377,396,430,431,928,944,1006,1013,1151,1160,1169,1179,1411) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,17,163,355,406,702,835,847,1083,1156,1183,1185,1200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Create the labels.
# By index:
# label 2 is transfers
# label 3 is premiums
# label 4 is costs
# label 5 is member months
# label 6 is reinsurance (individual group only)

ind_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                  "HHS RISK ADJUSTMENT TRANSFER AMOUNT (INDIVIDUAL MARKET, INCLUDING CATASTROPHIC)",
                  "1.1Directpremiumwritten2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "2.16Totalincurredclaims2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "7.4Membermonths2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "STATE", "REINSURANCE PAYMENT AMOUNT (OR NOT ELIGIBLE)"] # no more reinsurance as of 2017
ind_labels_15 = [label.replace('15', '16') for label in ind_labels_14]
ind_labels_16 = [label.replace('15', '17') for label in ind_labels_14]
ind_labels_17 = [label.replace('15', '18') for label in ind_labels_14][:-1]

sg_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                 "HHS RISK ADJUSTMENT TRANSFERS AMOUNT (SMALL GROUP MARKET)",
                  "1.1Directpremiumwritten7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "2.16Totalincurredclaims7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "7.4Membermonths7HealthInsuranceSMALLGROUPTotalasof3/31/15", "STATE"]
sg_labels_15 = [label.replace('15', '16') for label in sg_labels_14]
sg_labels_16 = [label.replace('15', '17') for label in sg_labels_14]
sg_labels_17 = [label.replace('15', '18') for label in sg_labels_14]

# %%
# Filter the data to include only the fields we want

ind_data_14 = data2014[ind_labels_14].dropna()
ind_data_15 = data2015[ind_labels_15].dropna()
ind_data_16 = data2016[ind_labels_16].dropna()
ind_data_17 = data2017[ind_labels_17].dropna()
sg_data_14 = data2014[sg_labels_14].dropna()
sg_data_15 = data2015[sg_labels_15].dropna()
sg_data_16 = data2016[sg_labels_16].dropna()
sg_data_17 = data2017[sg_labels_17].dropna()

# %%
# Drop companies with <2000 MM
ind_data_14 = ind_data_14.where(ind_data_14[ind_labels_14[5]] > 2000).dropna()
ind_data_15 = ind_data_15.where(ind_data_15[ind_labels_15[5]] > 2000).dropna()
ind_data_16 = ind_data_16.where(ind_data_16[ind_labels_16[5]] > 2000).dropna()
ind_data_17 = ind_data_17.where(ind_data_17[ind_labels_17[5]] > 2000).dropna()
sg_data_14 = sg_data_14.where(sg_data_14[sg_labels_14[5]] > 2000).dropna()
sg_data_15 = sg_data_15.where(sg_data_15[sg_labels_15[5]] > 2000).dropna()
sg_data_16 = sg_data_16.where(sg_data_16[sg_labels_16[5]] > 2000).dropna()
sg_data_17 = sg_data_17.where(sg_data_17[sg_labels_17[5]] > 2000).dropna()

# %%
# Calculate transfers, premiums, costs, and reinsurance (if individual group) per member month
def calculate_pmm(df, df_labels, group):
    df["MM"] = df[df_labels[5]]
    df["Transfers"] = df[df_labels[2]]
    df["TotalCosts"] = abs(df[df_labels[4]])
    df["Enrollees"] = df["MM"] / 12
    df["TransfersPerEnrollee"] = df["Transfers"] / df["Enrollees"]
    df["TransfersPerSqrtEnrollee"] = df["Transfers"] / np.sqrt(df["Enrollees"])
    df["LogEnrollees"] = np.log(df["Enrollees"])
    df["LogTransfers"] = np.log(df["Transfers"]**2 + 1)
    df["TransfersPMM"] = df[df_labels[2]] / df[df_labels[5]]
    df["PremiumsPMM"] = abs(df[df_labels[3]] / df[df_labels[5]])
    df["CostsPMM"] = abs(df[df_labels[4]] / df[df_labels[5]])
    if group == "i":
        df["ReinsurancePMM"] = df[df_labels[7]] / df[df_labels[5]]
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"] + df["ReinsurancePMM"]
        #df["PremMinusCostsPlusReinsurancePMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["ReinsurancePMM"]
    elif group == "sg":
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["PremMinusCostsPMM"] = df["PremiumsPMM"] - df["CostsPMM"]
    df["PremMinusCostsPlusTransfersPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["SicknessPMM"] = df["CostsPMM"] - df["PremiumsPMM"]
    average_sickness = np.mean(df["SicknessPMM"])
    df["ExcessSicknessPMM"] = df["SicknessPMM"] - average_sickness
    return df

ind_data_14 = calculate_pmm(ind_data_14, ind_labels_14, "i")
ind_data_15 = calculate_pmm(ind_data_15, ind_labels_15, "i")
ind_data_16 = calculate_pmm(ind_data_16, ind_labels_16, "i")
ind_data_17 = calculate_pmm(ind_data_17, ind_labels_17, "sg")
sg_data_14 = calculate_pmm(sg_data_14, sg_labels_14, "sg")
sg_data_15 = calculate_pmm(sg_data_15, sg_labels_15, "sg")
sg_data_16 = calculate_pmm(sg_data_16, sg_labels_16, "sg")
sg_data_17 = calculate_pmm(sg_data_17, sg_labels_17, "sg")

# %%
# Combine the dataframes by left merging

ind_data = ind_data_14.merge(ind_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(ind_data_16, on='HIOS ID', how='outer').merge(ind_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
# Do the same thing for small group

sg_data = sg_data_14.merge(sg_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(sg_data_16, on='HIOS ID', how='outer').merge(sg_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
states = list(set(sg_data_14["STATE"]))
dfs = [sg_data_14, sg_data_15, sg_data_16, sg_data_17]

# %%
dfs_new = normalize_empirical_data_split_randomly_for_years(dfs)
# Out:
# 310
# 247
# 195
# 228
# ME 14 Ratio is 1.096
# IL 14 Ratio is 0.998
# PA 14 Ratio is 1.018
# GA 14 Ratio is 1.161
# OK 14 Ratio is 1.147
# DE 14 Ratio is 1.063
# WA 14 Ratio is 1.105
# CT 14 Ratio is 0.913
# OH 14 Ratio is 1.165
# VA 14 Ratio is 1.152
# NE 14 Ratio is 1.166
# MT 14 Ratio is 1.092
# IN 14 Ratio is 1.162
# CA 14 Ratio is 1.064
# HI 14 Ratio is 1.083
# ND 14 Ratio is 1.108
# MD 14 Ratio is 1.142
# SC 14 Ratio is 1.028
# RI 14 Ratio is 0.930
# AK 14 Ratio is 0.703
# KY 14 Ratio is 1.280
# WI 14 Ratio is 1.039
# LA 14 Ratio is 1.092
# MN 14 Ratio is 1.089
# MS 14 Ratio is 1.254
# WV 14 Ratio is 0.952
# FL 14 Ratio is 1.106
# SD 15 Ratio is 1.010
# IL 15 Ratio is 0.959
# PA 15 Ratio is 0.988
# NH 15 Ratio is 0.960
# NM 15 Ratio is 1.021
# NV 15 Ratio is 1.200
# OK 15 Ratio is 1.053
# UT 15 Ratio is 1.392
# CT 15 Ratio is 0.901
# OH 15 Ratio is 1.098
# VA 15 Ratio is 1.170
# OR 15 Ratio is 1.049
# CO 15 Ratio is 1.093
# IN 15 Ratio is 1.085
# HI 15 Ratio is 1.001
# AL 15 Ratio is 1.011
# RI 15 Ratio is 0.993
# AK 15 Ratio is 0.654
# LA 15 Ratio is 0.996
# MN 15 Ratio is 1.065
# IA 15 Ratio is 1.174
# AR 15 Ratio is 1.297
# WV 15 Ratio is 0.970
# MI 16 Ratio is 1.101
# ME 16 Ratio is 1.029
# WY 16 Ratio is 0.827
# DC 16 Ratio is 0.969
# TX 16 Ratio is 0.925
# AZ 16 Ratio is 1.222
# NC 16 Ratio is 1.085
# WA 16 Ratio is 1.045
# OR 16 Ratio is 0.994
# CO 16 Ratio is 1.084
# MT 16 Ratio is 1.058
# ND 16 Ratio is 0.976
# TN 16 Ratio is 1.154
# SC 16 Ratio is 0.917
# AL 16 Ratio is 0.986
# NY 16 Ratio is 0.795
# KY 16 Ratio is 1.103
# NJ 16 Ratio is 0.851
# KS 16 Ratio is 1.049
# ID 16 Ratio is 1.213
# IA 16 Ratio is 1.122
# AR 16 Ratio is 1.203
# MO 16 Ratio is 1.102
# MI 17 Ratio is 1.079
# SD 17 Ratio is 0.896
# WY 17 Ratio is 0.854
# NH 17 Ratio is 0.855
# DC 17 Ratio is 0.912
# TX 17 Ratio is 0.899
# GA 17 Ratio is 0.959
# AZ 17 Ratio is 1.172
# NM 17 Ratio is 0.871
# NC 17 Ratio is 0.945
# NV 17 Ratio is 1.170
# DE 17 Ratio is 0.878
# UT 17 Ratio is 1.283
# NE 17 Ratio is 1.002
# CA 17 Ratio is 0.936
# MD 17 Ratio is 1.060
# TN 17 Ratio is 1.162
# NY 17 Ratio is 0.721
# NJ 17 Ratio is 0.785
# KS 17 Ratio is 0.940
# WI 17 Ratio is 0.926
# ID 17 Ratio is 1.179
# MS 17 Ratio is 1.073
# FL 17 Ratio is 0.964
# MO 17 Ratio is 1.064
# Empirical Transfers Sum = 3691451791.964

# %%
mm_total = 0
for adf in dfs_new:
    mm_total = mm_total + sum(adf["MM"])
print(mm_total)
# Out:
# 320364319.7871

# %%
for df_temp in dfs_new:
    df_temp["TransfersNormalizedPerSqrtEnrollee"] = df_temp["TransfersNormalized"] / np.sqrt(df_temp["Enrollees"])

# %%
df2 = create_df2_without_states(dfs_new, "TransfersNormalizedPerSqrtEnrollee")

# %%
k = len(df2)
v = np.linspace(0, max(abs(df2)), 10000)
v = v[1:len(v)]

ratios = [ratio_list(df2, vi) for vi in v]
#print(ratios)
begin_p = 5/k
end_p = 1-begin_p
start_index = 0
end_index = 0
for index, ratio2 in enumerate(ratios):
    if ratio2 >= begin_p:
        start_index = index
        break
    
for index, ratio2 in enumerate(ratios):
    if ratio2 > end_p:
        end_index = index
        break

if end_index == 0:
    end_index = len(v) - 1
    
v = v[start_index:end_index]

ratios2 = ratios[start_index:end_index]
multiplier = [np.sqrt(2)/vi for vi in v]
#plt.plot(v, ratios2)
#plt.plot(v, multiplier)

# %%
y = [multiplier[i] * special.erfinv(ratio2) for i, ratio2 in enumerate(ratios2)]
#plt.plot(v, y)
#plt.title("1/beta vs. v")
beta = [1/yi for yi in y]
#plt.plot(v, beta)
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
#plt.title("beta vs. v")

# %%
# Finding the minimum beta
# Whenever we reject a beta, we reject all betas greater than that,
# so keep pushing beta smaller until we reach max_difference == test_statistic
# Run test for larger data sizes (combining states, years)

# %%
max_beta=max(beta)
max_beta = int(max_beta/100)*100

# %%
state_label = "All States"

# %%
theoretical = [special.erf(vi/(max_beta*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v)")
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (state_label, len(df2)))
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
plt.legend()
print("beta = %.3f" % (max_beta))
# Out:
# beta = 106600.000

# %%
beta1, Mb_index = run_test_against_theoretical(df2, max_beta, ratios2)
# Out:
# k = 976
# test_stat at this k = 0.04347
#
# At the point of maximum difference with beta = 106600:
# P(|d_i|<v) = 0.8105
# P(|N(0,max_beta^2)|<v) = 0.2233
# Difference = 0.5872
#
#
#
#
# At the point of maximum difference with beta = 96600:
# P(|d_i|<v) = 0.8105
# P(|N(0,max_beta^2)|<v) = 0.2457
# Difference = 0.5648
#
#
#
#
# At the point of maximum difference with beta = 86600:
# P(|d_i|<v) = 0.8105
# P(|N(0,max_beta^2)|<v) = 0.2730
# Difference = 0.5375
#
#
#
#
# At the point of maximum difference with beta = 76600:
# P(|d_i|<v) = 0.8105
# P(|N(0,max_beta^2)|<v) = 0.3069
# Difference = 0.5036
#
#
#
#
# At the point of maximum difference with beta = 66600:
# P(|d_i|<v) = 0.8105
# P(|N(0,max_beta^2)|<v) = 0.3501
# Difference = 0.4604
#
#
#
#
# At the point of maximum difference with beta = 56600:
# P(|d_i|<v) = 0.8105
# P(|N(0,max_beta^2)|<v) = 0.4067
# Difference = 0.4037
#
#
#
#
# At the point of maximum difference with beta = 46600:
# P(|d_i|<v) = 0.6373
# P(|N(0,max_beta^2)|<v) = 0.2944
# Difference = 0.3429
#
#
#
#
# At the point of maximum difference with beta = 36600:
# P(|d_i|<v) = 0.6373
# P(|N(0,max_beta^2)|<v) = 0.3695
# Difference = 0.2678
#
#
#
#
# At the point of maximum difference with beta = 26600:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3630
# Difference = 0.1709
#
#
#
#
# At the point of maximum difference with beta = 26600:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3630
# Difference = 0.1709
#
#
#
#
# At the point of maximum difference with beta = 26500:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3642
# Difference = 0.1696
#
#
#
#
# At the point of maximum difference with beta = 26400:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3655
# Difference = 0.1683
#
#
#
#
# At the point of maximum difference with beta = 26300:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3668
# Difference = 0.1670
#
#
#
#
# At the point of maximum difference with beta = 26200:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3681
# Difference = 0.1657
#
#
#
#
# At the point of maximum difference with beta = 26100:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3694
# Difference = 0.1644
#
#
#
#
# At the point of maximum difference with beta = 26000:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3707
# Difference = 0.1631
#
#
#
#
# At the point of maximum difference with beta = 25900:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3720
# Difference = 0.1618
#
#
#
#
# At the point of maximum difference with beta = 25800:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3734
# Difference = 0.1605
#
#
#
#
# At the point of maximum difference with beta = 25700:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3747
# Difference = 0.1591
#
#
#
#
# At the point of maximum difference with beta = 25600:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3760
# Difference = 0.1578
#
#
#
#
# At the point of maximum difference with beta = 25500:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3774
# Difference = 0.1564
#
#
#
#
# At the point of maximum difference with beta = 25400:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3788
# Difference = 0.1550
#
#
#
#
# At the point of maximum difference with beta = 25300:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3802
# Difference = 0.1537
#
#
#
#
# At the point of maximum difference with beta = 25200:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3815
# Difference = 0.1523
#
#
#
#
# At the point of maximum difference with beta = 25100:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3829
# Difference = 0.1509
#
#
#
#
# At the point of maximum difference with beta = 25000:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3844
# Difference = 0.1495
#
#
#
#
# At the point of maximum difference with beta = 24900:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3858
# Difference = 0.1480
#
#
#
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3872
# Difference = 0.1466
#
#
#
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3886
# Difference = 0.1452
#
#
#
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.3901
# Difference = 0.1437
#
#
#
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.3895
# Difference = 0.1423
#
#
#
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.3910
# Difference = 0.1408
#
#
#
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.3924
# Difference = 0.1393
#
#
#
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.3939
# Difference = 0.1379
#
#
#
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.3954
# Difference = 0.1364
#
#
#
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.3969
# Difference = 0.1349
#
#
#
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.3984
# Difference = 0.1333
#
#
#
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.3999
# Difference = 0.1318
#
#
#
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4015
# Difference = 0.1303
#
#
#
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4030
# Difference = 0.1287
#
#
#
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4046
# Difference = 0.1272
#
#
#
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4062
# Difference = 0.1256
#
#
#
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4077
# Difference = 0.1240
#
#
#
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4093
# Difference = 0.1224
#
#
#
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4109
# Difference = 0.1208
#
#
#
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4126
# Difference = 0.1192
#
#
#
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4142
# Difference = 0.1176
#
#
#
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4158
# Difference = 0.1159
#
#
#
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4175
# Difference = 0.1143
#
#
#
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4192
# Difference = 0.1126
#
#
#
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4208
# Difference = 0.1109
#
#
#
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4225
# Difference = 0.1092
#
#
#
#
# At the point of maximum difference with beta = 22300:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4242
# Difference = 0.1075
#
#
#
#
# At the point of maximum difference with beta = 22200:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4260
# Difference = 0.1058
#
#
#
#
# At the point of maximum difference with beta = 22100:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4277
# Difference = 0.1041
#
#
#
#
# At the point of maximum difference with beta = 22000:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4294
# Difference = 0.1023
#
#
#
#
# At the point of maximum difference with beta = 21900:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4312
# Difference = 0.1006
#
#
#
#
# At the point of maximum difference with beta = 21800:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4330
# Difference = 0.0988
#
#
#
#
# At the point of maximum difference with beta = 21700:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4348
# Difference = 0.0970
#
#
#
#
# At the point of maximum difference with beta = 21600:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4366
# Difference = 0.0952
#
#
#
#
# At the point of maximum difference with beta = 21500:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4384
# Difference = 0.0934
#
#
#
#
# At the point of maximum difference with beta = 21400:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4402
# Difference = 0.0916
#
#
#
#
# At the point of maximum difference with beta = 21300:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4420
# Difference = 0.0897
#
#
#
#
# At the point of maximum difference with beta = 21200:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4439
# Difference = 0.0879
#
#
#
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2156
# Difference = 0.0866
#
#
#
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2166
# Difference = 0.0856
#
#
#
#
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2176
# Difference = 0.0846
#
#
#
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2187
# Difference = 0.0836
#
#
#
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2197
# Difference = 0.0826
#
#
#
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2207
# Difference = 0.0815
#
#
#
#
# At the point of maximum difference with beta = 20500:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2218
# Difference = 0.0805
#
#
#
#
# At the point of maximum difference with beta = 20400:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2228
# Difference = 0.0794
#
#
#
#
# At the point of maximum difference with beta = 20300:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2239
# Difference = 0.0784
#
#
#
#
# At the point of maximum difference with beta = 20200:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2250
# Difference = 0.0773
#
#
#
#
# At the point of maximum difference with beta = 20100:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2014
# Difference = 0.0763
#
#
#
#
# At the point of maximum difference with beta = 20000:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2024
# Difference = 0.0753
#
#
#
#
# At the point of maximum difference with beta = 19900:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2033
# Difference = 0.0743
#
#
#
#
# At the point of maximum difference with beta = 19800:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2044
# Difference = 0.0733
#
#
#
#
# At the point of maximum difference with beta = 19700:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2054
# Difference = 0.0723
#
#
#
#
# At the point of maximum difference with beta = 19600:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2064
# Difference = 0.0713
#
#
#
#
# At the point of maximum difference with beta = 19500:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2074
# Difference = 0.0702
#
#
#
#
# At the point of maximum difference with beta = 19400:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2085
# Difference = 0.0692
#
#
#
#
# At the point of maximum difference with beta = 19300:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2095
# Difference = 0.0681
#
#
#
#
# At the point of maximum difference with beta = 19200:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2106
# Difference = 0.0671
#
#
#
#
# At the point of maximum difference with beta = 19100:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2117
# Difference = 0.0660
#
#
#
#
# At the point of maximum difference with beta = 19000:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2128
# Difference = 0.0649
#
#
#
#
# At the point of maximum difference with beta = 18900:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2139
# Difference = 0.0638
#
#
#
#
# At the point of maximum difference with beta = 18800:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2150
# Difference = 0.0627
#
#
#
#
# At the point of maximum difference with beta = 18700:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2161
# Difference = 0.0616
#
#
#
#
# At the point of maximum difference with beta = 18600:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2172
# Difference = 0.0605
#
#
#
#
# At the point of maximum difference with beta = 18500:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2184
# Difference = 0.0593
#
#
#
#
# At the point of maximum difference with beta = 18400:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2195
# Difference = 0.0581
#
#
#
#
# At the point of maximum difference with beta = 18300:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2207
# Difference = 0.0570
#
#
#
#
# At the point of maximum difference with beta = 18200:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2219
# Difference = 0.0558
#
#
#
#
# At the point of maximum difference with beta = 18100:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2231
# Difference = 0.0546
#
#
#
#
# At the point of maximum difference with beta = 18000:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2243
# Difference = 0.0534
#
#
#
#
# At the point of maximum difference with beta = 17900:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2255
# Difference = 0.0522
#
#
#
#
# At the point of maximum difference with beta = 17800:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2267
# Difference = 0.0509
#
#
#
#
# At the point of maximum difference with beta = 17700:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2280
# Difference = 0.0497
#
#
#
#
# At the point of maximum difference with beta = 17600:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2292
# Difference = 0.0484
#
#
#
#
# At the point of maximum difference with beta = 17500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0735
# Difference = 0.0474
#
#
#
#
# At the point of maximum difference with beta = 17400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0739
# Difference = 0.0470
#
#
#
#
# At the point of maximum difference with beta = 17300:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0743
# Difference = 0.0466
#
#
#
#
# At the point of maximum difference with beta = 17200:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0747
# Difference = 0.0462
#
#
#
#
# At the point of maximum difference with beta = 17100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0752
# Difference = 0.0457
#
#
#
#
# At the point of maximum difference with beta = 17000:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0756
# Difference = 0.0453
#
#
#
#
# At the point of maximum difference with beta = 16900:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0761
# Difference = 0.0448
#
#
#
#
# At the point of maximum difference with beta = 16800:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0765
# Difference = 0.0444
#
#
#
#
# At the point of maximum difference with beta = 16700:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0770
# Difference = 0.0439

# %%
beta1 = beta1+100

theoretical = [special.erf(vi/(beta1*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) beta=%d" % (beta1))
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (state_label, len(df2)))
plt.axvline(x=v[Mb_index], color='r', linestyle='--', label="Point of max difference")
plt.legend()
#plt.xlim(0, 50000)
#print("beta = %.3f" % (max_beta))

# %%
run_binom_stat_test2(beta1, df2.values)
# Out:
# Beta (=std): 16700
# Number of T/sqrt(n) above 2 stds: 169
# Proportion of T/sqrt(n) above 2 stds: 0.173
# P value = 0.000000

# %%
#df3 = create_df3(states, dfs_new)

# %%
ratios_c, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta1 - 10000)
ratios_c2, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta1)
ratios_c3, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta1 + 10000)
# Out:
# Sum sqrt(a) = 102167.338
# Sum sqrt(a) = 102167.338
# Sum sqrt(a) = 102167.338

# %%
theoretical = [special.erf(vi/(beta1*np.sqrt(2))) for vi in v]

plt.figure(figsize=(10, 7))
plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) with beta = %d" % (beta1))
plt.plot(v, ratios2, label="P(|d_i|<v) = empirical distribution")
plt.plot(v, ratios_c, label="Simulation with es = %d, 5 times" % (beta1 - 10000))
plt.plot(v, ratios_c2, label="Simulation with es = %d, 5 times" % (beta1))
plt.plot(v, ratios_c3, label="Simulation with es = %d, 5 times" % (beta1 + 10000))
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s (k=%d)" % (state_label, len(df2)))
plt.legend()

# %%
beta1, _ = run_test_against_simulation_adjust_for_imbalances(states, dfs_new, beta1, ratios2)
# Out:
# k = 976
# test_stat at this k = 0.04347
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 16700:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0894
# Difference = 0.0315 NOT > test_stat
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 26700:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.4005
# Difference = 0.1333
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 26600:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.4109
# Difference = 0.1230
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 26500:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.3977
# Difference = 0.1340
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 26400:
# P(|d_i|<v) = 0.5328
# P(|N(0,max_beta^2)|<v) = 0.4040
# Difference = 0.1288
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 26300:
# P(|d_i|<v) = 0.5328
# P(|N(0,max_beta^2)|<v) = 0.4149
# Difference = 0.1179
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 26200:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4157
# Difference = 0.1161
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 26100:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4181
# Difference = 0.1137
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 26000:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.4228
# Difference = 0.1110
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 25900:
# P(|d_i|<v) = 0.5328
# P(|N(0,max_beta^2)|<v) = 0.4197
# Difference = 0.1131
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 25800:
# P(|d_i|<v) = 0.5328
# P(|N(0,max_beta^2)|<v) = 0.4154
# Difference = 0.1174
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 25700:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4210
# Difference = 0.1108
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 25600:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.4260
# Difference = 0.1079
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 25500:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4208
# Difference = 0.1110
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 25400:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4320
# Difference = 0.0998
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 25300:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4287
# Difference = 0.1031
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 25200:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4275
# Difference = 0.1043
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 25100:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4329
# Difference = 0.0988
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 25000:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.4257
# Difference = 0.1081
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 24900:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4349
# Difference = 0.0969
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4273
# Difference = 0.1044
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4371
# Difference = 0.0947
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.5328
# P(|N(0,max_beta^2)|<v) = 0.4409
# Difference = 0.0919
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4346
# Difference = 0.0971
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4376
# Difference = 0.0941
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2143
# Difference = 0.0880
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2164
# Difference = 0.0859
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4452
# Difference = 0.0865
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2157
# Difference = 0.0865
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2173
# Difference = 0.0850
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.1952
# Difference = 0.0824
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.4477
# Difference = 0.0861
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2225
# Difference = 0.0797
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2270
# Difference = 0.0753
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2214
# Difference = 0.0809
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2212
# Difference = 0.0810
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2231
# Difference = 0.0792
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.1962
# Difference = 0.0815
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2262
# Difference = 0.0760
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2266
# Difference = 0.0756
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2313
# Difference = 0.0710
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2048
# Difference = 0.0729
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2057
# Difference = 0.0720
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2070
# Difference = 0.0707
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2365
# Difference = 0.0657
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 22300:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2091
# Difference = 0.0686
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 22200:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2365
# Difference = 0.0657
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 22100:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2324
# Difference = 0.0698
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 22000:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2127
# Difference = 0.0650
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21900:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2325
# Difference = 0.0697
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21800:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2089
# Difference = 0.0687
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21700:
# P(|d_i|<v) = 0.2756
# P(|N(0,max_beta^2)|<v) = 0.2089
# Difference = 0.0667
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21600:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2141
# Difference = 0.0636
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21500:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2163
# Difference = 0.0613
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21400:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2225
# Difference = 0.0551
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21300:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2177
# Difference = 0.0600
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21200:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2186
# Difference = 0.0590
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2152
# Difference = 0.0625
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2167
# Difference = 0.0609
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2265
# Difference = 0.0512
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2258
# Difference = 0.0519
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2275
# Difference = 0.0502
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.1383
# P(|N(0,max_beta^2)|<v) = 0.0900
# Difference = 0.0483
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20500:
# P(|d_i|<v) = 0.1383
# P(|N(0,max_beta^2)|<v) = 0.0902
# Difference = 0.0482
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0746
# Difference = 0.0463
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20300:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2277
# Difference = 0.0499
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20200:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2305
# Difference = 0.0472
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20100:
# P(|d_i|<v) = 0.2756
# P(|N(0,max_beta^2)|<v) = 0.2320
# Difference = 0.0436
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20000:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2284
# Difference = 0.0492
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 19900:
# P(|d_i|<v) = 0.1383
# P(|N(0,max_beta^2)|<v) = 0.0920
# Difference = 0.0463
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 19800:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0759
# Difference = 0.0450
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 19700:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0729
# Difference = 0.0480
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 19600:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0791
# Difference = 0.0418 NOT > test_stat
# E(|X|) = 901432630.512

# %%
run_binom_stat_test2(beta1, df2.values)
# Out:
# Beta (=std): 19600
# Number of T/sqrt(n) above 2 stds: 139
# Proportion of T/sqrt(n) above 2 stds: 0.142
# P value = 0.000000
